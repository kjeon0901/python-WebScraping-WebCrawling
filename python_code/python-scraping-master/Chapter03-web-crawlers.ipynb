# %%
############# 케빈 베이컨의 6단계 법칙 #############
'''
인간관계는 6단계만 거치면 지구상 대부분의 사람과 연결될 수 있다는 사회 이론
'''

from urllib.request import urlopen
from bs4 import BeautifulSoup 

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs: # link.attrs : link라는 태그(a 태그 中 하나)가 가진 속성들
        print(link.attrs['href']) # href 속성의 value값 출력 
'''
/wiki/Wikipedia:Protection_policy#semi
#mw-head
#searchInput
/wiki/Kevin_Bacon_(disambiguation)
/wiki/File:Kevin_Bacon_SDCC_2014.jpg
/wiki/Philadelphia,_Pennsylvania
/wiki/Kyra_Sedgwick
/wiki/Sosie_Bacon
#cite_note-1
/wiki/Edmund_Bacon_(architect)
/wiki/Michael_Bacon_(musician)
/wiki/Holly_Near
http://baconbros.com/
  ㆍㆍㆍ
엄청 많음!
'''
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #searchInput
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# #cite_note-1
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# http://baconbros.com/
# #cite_note-2
# #cite_note-actor-3
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/X-Men:_First_Class
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/Streaming_television
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-6
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-3
# #cite_note-actor-3
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_High_School
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-6
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-7
# #cite_note-16
# #cite_note-17
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-18
# /wiki/Tremors_(1990_film)
# #cite_note-19
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-20
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-21
# /wiki/A_Few_Good_Men_(film)
# #cite_note-22
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-23
# /wiki/Sleepers_(film)
# #cite_note-24
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-25
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-26
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-27
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-28
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-29
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-30
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-31
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# #cite_note-32
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-33
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-34
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-35
# #cite_note-36
# /wiki/The_Following
# #cite_note-37
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-38
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-39
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# #cite_note-40
# #cite_note-41
# #cite_note-42
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-43
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-44
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-45
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-46
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-47
# /wiki/Tracy_Pollan
# #cite_note-48
# #cite_note-49
# #cite_note-50
# /wiki/The_Times
# #cite_note-51
# #cite_note-52
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-53
# #cite_note-54
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-55
# #cite_note-56
# #cite_note-57
# #cite_note-58
# /wiki/Apollo_13_(film)
# #cite_note-59
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-60
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-61
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-62
# /wiki/Denver_Film_Festival
# #cite_note-63
# /wiki/Phoenix_Film_Festival
# #cite_note-64
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-65
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-66
# /wiki/Seattle_International_Film_Festival
# #cite_note-67
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# http://www.geneall.net/U/per_page.php?id=1014399
# #cite_ref-2
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_3-0
# #cite_ref-actor_3-1
# #cite_ref-actor_3-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_6-0
# #cite_ref-walk_6-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-19
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_20-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-21
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-22
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-23
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-24
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_25-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-26
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-27
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-28
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-29
# https://archive.is/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-30
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-31
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-32
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-33
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_34-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_35-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# #cite_ref-36
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-37
# http://www.fox.com/the-following/
# #cite_ref-38
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-39
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-40
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-41
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-42
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-43
# http://www.sixdegrees.org/
# #cite_ref-44
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-45
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-46
# http://baconbros.com/
# #cite_ref-47
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-48
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-49
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-50
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-51
# #cite_ref-52
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_53-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-54
# #cite_ref-55
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-56
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-57
# http://www.drawtheline.org/sign-now/
# #cite_ref-58
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-59
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-60
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-61
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-62
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-63
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-64
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-65
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-66
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-67
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.lortel.org/Archives/CreditableEntity/5597
# /wiki/Lortel_Archives
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# https://en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# https://en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# https://en.wikipedia.org/w/index.php?title=Template:Golden_Globe_Best_Actor_TV_Miniseries_Film&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# https://en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# https://d-nb.info/gnd/124109659
# /wiki/ISNI_(identifier)
# https://isni.org/isni/0000000121291300
# /wiki/VIAF_(identifier)
# https://viaf.org/viaf/39570812
# https://www.worldcat.org/identities/lccn-n88034930
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://id.loc.gov/authorities/names/n88034930
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://nla.gov.au/anbd.aut-an36021861
# http://uli.nli.org.il/F/?func=direct&doc_number=002168993&local_base=nlx10
# http://data.bibliotheken.nl/id/thes/p147880998
# http://mak.bn.org.pl/cgi-bin/KHW/makwww.exe?BM=1&NU=1&IM=4&WI=9810630778405606
# http://id.worldcat.org/fast/242183/
# /wiki/MBA_(identifier)
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/RERO_(identifier)
# http://data.rero.ch/02-A016294166
# https://snaccooperative.org/ark:/99166/w6w67gw2
# /wiki/SUDOC_(identifier)
# https://www.idref.fr/084292652
# https://www.idref.fr/067287832
# /wiki/Trove_(identifier)
# https://trove.nla.gov.au/people/1189569
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1025576864
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:Articles_with_IBDb_links
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_ISNI_identifiers
# /wiki/Category:Wikipedia_articles_with_VIAF_identifiers
# /wiki/Category:Wikipedia_articles_with_BIBSYS_identifiers
# /wiki/Category:Wikipedia_articles_with_BNE_identifiers
# /wiki/Category:Wikipedia_articles_with_BNF_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Wikipedia_articles_with_LNB_identifiers
# /wiki/Category:Wikipedia_articles_with_NKC_identifiers
# /wiki/Category:Wikipedia_articles_with_NLA_identifiers
# /wiki/Category:Wikipedia_articles_with_NLI_identifiers
# /wiki/Category:Wikipedia_articles_with_NTA_identifiers
# /wiki/Category:Wikipedia_articles_with_PLWABN_identifiers
# /wiki/Category:Wikipedia_articles_with_FAST_identifiers
# /wiki/Category:Wikipedia_articles_with_MusicBrainz_identifiers
# /wiki/Category:Wikipedia_articles_with_RERO_identifiers
# /wiki/Category:Wikipedia_articles_with_SNAC-ID_identifiers
# /wiki/Category:Wikipedia_articles_with_SUDOC_identifiers
# /wiki/Category:Wikipedia_articles_with_Trove_identifiers
# /wiki/Category:Wikipedia_articles_with_WORLDCATID_identifiers
# /wiki/Category:Wikipedia_articles_with_multiple_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1025576864
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1025576864&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_B%C4%93kons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(  # link : 아래 find_all 만족시키는 a태그들 中 하나
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):           # a태그의 속성에 대한 정규표현식
    '''
    '^(/wiki/)((?!:).)*$'
        => ^  → 바로 뒤의 문자 or 표현식으로 문자열 시작해야 함. ^( ) 괄호로 묶으면 문자열도 가능
        => $  → 바로 앞의 문자 or 표현식으로 문자열 끝내야 함. 안 써주면 뒤에 더 와도 되므로, 피하고 싶은 애들을 완벽히 제외하려면 써줌. 
        => ?! → 바로 뒤의 문자 or 표현식은 오면 안 됨
        => ?= → 바로 뒤의 문자 or 표현식은 와야 됨
        ▶ 문자열은 /wiki/로 시작하고, :가 포함되지 않는 아무 문자열 오고 나면 끝난다. 
        ▶ $ 안써주면 뒤에 :, 개행 등 더 와도 앞부분만 match되면 ㄱㅊ. :를 완벽히 제외하지 못하게 됨. 
    '''
    if 'href' in link.attrs:     # for문에서 걸러낸 link의 속성 中 href가 있다면
        print(link.attrs['href']) # 그 href 속성의 value값 출력
'''
/wiki/Kevin_Bacon_(disambiguation)
/wiki/San_Diego_Comic-Con
/wiki/Philadelphia
/wiki/Pennsylvania
/wiki/Kyra_Sedgwick
/wiki/Sosie_Bacon
/wiki/Edmund_Bacon_(architect)
/wiki/Michael_Bacon_(musician)
/wiki/Footloose_(1984_film)
/wiki/JFK_(film)
/wiki/A_Few_Good_Men
/wiki/Apollo_13_(film)
  ㆍㆍㆍ
엄청 많음! 그래도 이제 '^(/wiki/)((?!:).)*$' 에 해당되는 속성값만 출력됨. 
계속 다른 영화, 다른 배우에 관한 위키백과로만 타고 타고 .. 들어가기 위해서 이렇게 걸러준 것임. 
'''
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/San_Diego_Comic-Con
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/People_(American_magazine)
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(film)
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# /wiki/Egg_as_food
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/The_Times
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernard_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Broadcast_Film_Critics_Association_Awards
# /wiki/Broadcast_Film_Critics_Association_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/MTV_Movie_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics_Awards
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture_Drama
# /wiki/The_Woodsman_(2004_film)
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Awards
# /wiki/Beauty_Shop
# /wiki/Primetime_Emmy_Awards
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Miniseries_or_a_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Awards
# /wiki/Saturn_Awards
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/People%27s_Choice_Awards
# /wiki/People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Saturn_Awards
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Golden_Globe_Awards
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/Reuters
# /wiki/CBS_News
# /wiki/The_Verge
# /wiki/The_Hollywood_Reporter
# /wiki/Indie_Wire
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Lortel_Archives
# /wiki/AllMovie
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Tom_Hanks
# /wiki/Ed_Harris
# /wiki/Bill_Paxton
# /wiki/Kathleen_Quinlan
# /wiki/Gary_Sinise
# /wiki/The_Birdcage
# /wiki/Hank_Azaria
# /wiki/Christine_Baranski
# /wiki/Dan_Futterman
# /wiki/Gene_Hackman
# /wiki/Nathan_Lane
# /wiki/Dianne_Wiest
# /wiki/Robin_Williams
# /wiki/The_Full_Monty
# /wiki/Mark_Addy
# /wiki/Paul_Barber_(actor)
# /wiki/Robert_Carlyle
# /wiki/Steve_Huison
# /wiki/Bruce_Jones_(actor)
# /wiki/Lesley_Sharp
# /wiki/William_Snape
# /wiki/Hugo_Speer
# /wiki/Tom_Wilkinson
# /wiki/Emily_Woof
# /wiki/Shakespeare_in_Love
# /wiki/Ben_Affleck
# /wiki/Simon_Callow
# /wiki/Jim_Carter_(actor)
# /wiki/Martin_Clunes
# /wiki/Judi_Dench
# /wiki/Joseph_Fiennes
# /wiki/Colin_Firth
# /wiki/Gwyneth_Paltrow
# /wiki/Geoffrey_Rush
# /wiki/Antony_Sher
# /wiki/Imelda_Staunton
# /wiki/American_Beauty_(1999_film)
# /wiki/Annette_Bening
# /wiki/Wes_Bentley
# /wiki/Thora_Birch
# /wiki/Chris_Cooper
# /wiki/Peter_Gallagher
# /wiki/Allison_Janney
# /wiki/Kevin_Spacey
# /wiki/Mena_Suvari
# /wiki/Traffic_(2000_film)
# /wiki/Steven_Bauer
# /wiki/Benjamin_Bratt
# /wiki/James_Brolin
# /wiki/Don_Cheadle
# /wiki/Erika_Christensen
# /wiki/Clifton_Collins_Jr.
# /wiki/Benicio_del_Toro
# /wiki/Michael_Douglas
# /wiki/Miguel_Ferrer
# /wiki/Albert_Finney
# /wiki/Topher_Grace
# /wiki/Luis_Guzm%C3%A1n
# /wiki/Amy_Irving
# /wiki/Tomas_Milian
# /wiki/D._W._Moffett
# /wiki/Dennis_Quaid
# /wiki/Peter_Riegert
# /wiki/Jacob_Vargas
# /wiki/Catherine_Zeta-Jones
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Virtual_International_Authority_File
# /wiki/Library_of_Congress_Control_Number
# /wiki/International_Standard_Name_Identifier
# /wiki/Integrated_Authority_File
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Biblioth%C3%A8que_nationale_de_France
# /wiki/MusicBrainz
# /wiki/SNAC

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now()) # 시드값(랜덤수행방법)
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl)) 
                # http://en.wikipedia.org : 서버주소
                # {} 안에 articleUrl 넣어줌 => http://en.wikipedia.org/wiki/Kevin_Bacon : 페이지주소
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon') # href=re.compile('^(/wiki/)((?!:).)*$') 만족하는 a태그들만 담김
while len(links) > 0: # 무한루프
    newArticle = links[random.randint(0, len(links)-1)].attrs['href'] # 균일분포로 뽑은 랜덤한 a태그 하나의 href값(링크) 담음
    '''
    np.random.randint(m, n) : 균일분포에서 m ~ n-1 사이의 랜덤 숫자 1개 뽑기. m 안써주면 0부터~
    np.random.rand(m, n) : 0 ~ 1 의 '균일분포 표준정규분포' 랜덤 숫자를 (m, n) 크기로 생성.
        균일분포 == 상수함수(연속) : 샘플링한 값의 range가 0 ~ 1이고 0.3 ~ 0,4 사이의 그래프와 x축간의 면적은 "0.3 ~ 0.4 사이의 값이 뽑힐 확률"
                                    떨어진 간극만 같다면 걔네의 면적, 즉 확률도 같다. 
    np.random.randn(m, n) : 평균 0, 표준편차 1의 '가우시안 표준정규분포' 랜덤 숫자를 (m, n) 크기로 생성
        정규분포 : 0.3 ~ 0.4 사이의 값이 뽑힐 확률과 0.4 ~ 0.5 사이의 값이 뽑힐 확률이 다르다. ex_히스토그램 distplot(정규분포, kde=True)
    np.random.normal(평균, 표준편차, size) : 주어진 평균, 표준편차의 정규분포를 size만큼 생성
    '''
    print(newArticle)
    links = getLinks(newArticle) # 현재 a태그 속성 href값(링크) 안의 또다른 a태그를 가져옴. 
'''
/wiki/Phoenix_Film_Festival
/wiki/Mad_Hot_Ballroom
/wiki/Fiorello_H._LaGuardia_High_School
/wiki/The_Beacon_School
/wiki/Innovation_Diploma_Plus_High_School
/wiki/Little_Red_School_House
/wiki/New_York_School_of_Applied_Design_for_Women
/wiki/Rice_High_School_(New_York)
/wiki/High_School_of_Fashion_Industries
/wiki/Hewitt_School
  ㆍㆍㆍ
이제는 실제로 링크 안의 링크로, 또 그 안의 링크로 .. 타고 타고 들어가는 Crawler 만들어짐. 
이런 코드 안에 어떤 동작을 하도록 기능을 넣어주면 Crawler가 동작하게 됨. 
'''
# Out:
# /wiki/Phoenix_Film_Festival
# /wiki/Mad_Hot_Ballroom
# /wiki/Fiorello_H._LaGuardia_High_School
# /wiki/The_Beacon_School
# /wiki/Innovation_Diploma_Plus_High_School
# /wiki/Little_Red_School_House
# /wiki/New_York_School_of_Applied_Design_for_Women
# /wiki/Rice_High_School_(New_York)
# /wiki/High_School_of_Fashion_Industries
# /wiki/Hewitt_School
# /wiki/New_York_Public_Library_Main_Branch
# /wiki/Mid-Manhattan_Library
# /wiki/Opportunity_Charter_School
# /wiki/La_Scuola_d%27Italia_Guglielmo_Marconi
# /wiki/Buckley_School_(New_York_City)
# /wiki/Morgan_Stanley
# /wiki/ISSN_(identifier)
# /wiki/ISO_31-4
# /wiki/IS-IS
# /wiki/ISO/IEC_29110
# /wiki/ISO/IEC_2022
# /wiki/ISO/IEC_6523
# /wiki/IEC_60364
# /wiki/Document_Style_Semantics_and_Specification_Language
# /wiki/ISO_8373
# /wiki/Computer_Graphics_Metafile
# /wiki/ISO/IEC_7816
# /wiki/JPEG_2000
# /wiki/APNG
# /wiki/Better_Portable_Graphics
# /wiki/Enhanced_Metafile
# /wiki/JPEG_XL
# /wiki/GIMP
# /wiki/Dconf
# /wiki/Scanner_Access_Now_Easy#Simple_Scan
# /wiki/List_of_office_suites
# /wiki/OfficeSuite
# /wiki/Microsoft_Windows
# /wiki/OLE_Automation
# /wiki/Hyper-V
# /wiki/Graphics_Device_Interface
# /wiki/HyperTerminal
# /wiki/YMODEM
# /wiki/XMODEM
# /wiki/Modem
# /wiki/Radio_wave
# /wiki/Electromagnetic_spectrum
# /wiki/Brown
# /wiki/Chromophore
# /wiki/Chroma_key
# /wiki/Lawrence_W._Butler
# /wiki/That_Hamilton_Woman
# /wiki/That_Night_in_London
# /wiki/Action_for_Slander
# /wiki/Muir_Mathieson
# /wiki/Vertigo_(film)
# /wiki/Alfred_Hitchcock_Presents_(1985_TV_series)
# /wiki/Stage_Fright_(1950_film)
# /wiki/Secret_Agent_(1936_film)
# /wiki/The_First_Born_(1928_film)
# /wiki/Jassy_(film)
# /wiki/Blighty_(film)
# /wiki/Miranda_(1948_film)
# /wiki/Love_Story_(1944_film)
# /wiki/Sydney
# /wiki/Northern_Beaches_Council
# /wiki/Elanora_Heights,_New_South_Wales
# /wiki/Divisions_of_the_Australian_House_of_Representatives
# /wiki/Division_of_Franklin
# /wiki/Barnes_Bay,_Tasmania
# /wiki/Dover,_Tasmania
# /wiki/Postcodes_in_Australia
# /wiki/Postal_codes_in_French_Polynesia
# /wiki/Postcodes_in_Australia
# /wiki/Victoria_(Australia)
# /wiki/Gippsland
# /wiki/Tarra-Bulga_National_Park
# /wiki/Geographic_coordinate_system
# /wiki/Institut_national_de_l%27information_g%C3%A9ographique_et_foresti%C3%A8re
# /wiki/Road_map
# /wiki/Black_Sea
# /wiki/Yalta
# /wiki/Premier_of_the_Soviet_Union
# /wiki/List_of_Russian_philosophers
# /wiki/Incompatibilism
# /wiki/Philosophical_zombie
# /wiki/Michael_P._Lynch
# /wiki/Edward_S._Herman
# /wiki/Propaganda_model
# /wiki/News_style
# /wiki/Journalistic_objectivity
# /wiki/Opinion_journalism
# /wiki/Code_of_ethics_in_media
# /wiki/Meteorology
# /wiki/Structure_of_the_Earth
# /wiki/ISBN_(identifier)
# /wiki/ISO_25178
# /wiki/Envelope
# /wiki/United_Kingdom
# /wiki/British_Overseas_Territories
# /wiki/Brexit_withdrawal_agreement
# /wiki/Lithuania%E2%80%93United_Kingdom_relations
# /wiki/India%E2%80%93Lithuania_relations
# /wiki/Indian_foreign_aid
# /wiki/France%E2%80%93India_relations
# /wiki/India-Cabo_Verde_relations
# /wiki/India_and_the_Non-Aligned_Movement
# /wiki/Grenada%E2%80%93India_relations
# /wiki/Georgia%E2%80%93India_relations
# /wiki/Georgia%E2%80%93Mexico_relations
# /wiki/Mexico%E2%80%93Namibia_relations
# /wiki/Mexico%E2%80%93Romania_relations
# /wiki/Romania%E2%80%93Syria_relations
# /wiki/China%E2%80%93Romania_relations
# /wiki/Romania%E2%80%93United_Kingdom_relations
# /wiki/Estonia%E2%80%93United_Kingdom_relations
# /wiki/Multilateralism
# /wiki/North_American_Free_Trade_Agreement
# /wiki/National_Constitution_Center#NCC_and_presidents
# /wiki/Economy_of_Philadelphia
# /wiki/Transportation_in_Philadelphia
# /wiki/List_of_NJ_Transit_bus_routes_(300%E2%80%93399)
# /wiki/Paoli/Thorndale_Line
# /wiki/OurBus
# /wiki/Martz_Group
# /wiki/Peter_Pan_Bus_Lines
# /wiki/Downeaster_(train)
# /wiki/Quincy,_Massachusetts
# /wiki/Avon,_Massachusetts
# /wiki/Population_Estimates_Program
# /wiki/United_States_Census
# /wiki/New_York_(state)
# /wiki/New_York_City_metropolitan_area
# /wiki/Fuzhou_Americans
# /wiki/Amerasian
# /wiki/Domestic_violence
# /wiki/American_Journal_of_Psychiatry
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/Retraction
# /wiki/Social_media
# /wiki/News_media
# /wiki/Occupation_(protest)
# /wiki/Slogan
# /wiki/Historical_negationism
# /wiki/Armenian_genocide_denial
# /wiki/Ghana%E2%80%93Turkey_relations
# /wiki/Turkey
# /wiki/%C4%B0stanbul_Airport
# /wiki/Moi_International_Airport
# /wiki/KLM
# /wiki/Etihad_Airways
# /wiki/Royal_Air_Maroc
# /wiki/Ghana_Airways
# /wiki/Smile_Air
# /wiki/Afra_Airlines
# /wiki/MK_Airlines
# /wiki/Boeing_747-200
# /wiki/McDonnell_Douglas_DC-10
# /wiki/Design_flaw
# /wiki/Product_safety
# /wiki/Consumer_protection
# /wiki/Telephone_Consumer_Protection_Act
# /wiki/Federal_appeals_court
# /wiki/Judiciary_Act_of_1789
# /wiki/Tort
# /wiki/Codification_(law)
# /wiki/Prosecutor
# /wiki/Police_in_Scotland
# /wiki/Scottish_Crime_and_Drug_Enforcement_Agency
# /wiki/Derbyshire_Constabulary
# /wiki/West_Mercia_Police
# /wiki/Essex_Police
# /wiki/Essex_Police,_Fire_and_Crime_Commissioner
# /wiki/Northamptonshire_Police,_Fire_and_Crime_Commissioner
# /wiki/Dafydd_Llywelyn_(politician)
# /wiki/Donna_Jones_(British_politician)
# /wiki/Dafydd_Llywelyn_(politician)
# /wiki/Devon_and_Cornwall_Police_and_Crime_Commissioner
# /wiki/Dafydd_Llywelyn_(politician)
# /wiki/Criminology
# /wiki/Macroeconomics
# /wiki/Fiscal_policy
# /wiki/Index_of_economics_articles
# /wiki/Hyperinflation
# /wiki/Expeditionary_economics
# /wiki/John_Stuart_Mill
# /wiki/Modern_liberalism_in_the_United_States
# /wiki/Liberalism_and_radicalism_in_Chile
# /wiki/Free_market
# /wiki/Liberalism_and_centrism_in_Finland
# /wiki/Hu_Shih
# /wiki/John_Dewey
# /wiki/Philip_Zimbardo
# /wiki/Robert_J._Resnick
# /wiki/Florence_Denmark
# /wiki/S2CID_(identifier)
# /wiki/Monograph
# /wiki/Bookbinding
# /wiki/Hardcover
# /wiki/Academic_book
# /wiki/S2CID_(identifier)
# /wiki/Scopus
# /wiki/Review_article
# /wiki/Research_question
# /wiki/Applied_science
# /wiki/General_Certificate_of_Secondary_Education
# /wiki/ISBN_(identifier)
# /wiki/ISO_5426
# /wiki/ISO/IEC_8859-3
# /wiki/Code_page_1277
# /wiki/Soft_hyphen
# /wiki/Bamum_script
# /wiki/Specials_(Unicode_block)#Replacement_character
# /wiki/Pollard_script
# /wiki/Ghanaian_braille
# /wiki/Nigerian_braille
# /wiki/Navajo_Braille
# /wiki/Taiwanese_Braille
# /wiki/Dungan_language#Writing_system
# /wiki/Gong_language
# /wiki/Sa%27och_language
# /wiki/Monic_languages
# /wiki/Apis_dorsata
# /wiki/Indian_subcontinent
# /wiki/Cosmonauts_Sea
# /wiki/Superocean
# /wiki/Moro_Gulf
# /wiki/Sibuguey_Bay
# /wiki/Zamboanga_Peninsula_(geographical_region)
# /wiki/Philippines
# /wiki/ISBN_(identifier)
# /wiki/Vicat_softening_point
# /wiki/Business_Process_Model_and_Notation
# /wiki/S2CID_(identifier)
# /wiki/List_of_style_guides#Academic
# /wiki/European_Union
# /wiki/Treaty_on_the_Functioning_of_the_European_Union
# /wiki/Sweden
# /wiki/Jet_aircraft
# /wiki/Lockheed_Martin_F-35_Lightning_II
# /wiki/Knesset
# /wiki/Assembly_of_the_Union_of_the_Comoros
# /wiki/National_Assembly_(Communist_Czechoslovakia)
# /wiki/Knesset
# /wiki/Seventeenth_government_of_Israel
# /wiki/Twenty-eighth_government_of_Israel
# /wiki/Yossi_Beilin
# /wiki/Ministry_of_Religious_Services
# /wiki/Yitzhak_Vaknin
# /wiki/Haim_Yosef_Zadok
# /wiki/Palestinians
# /wiki/Al-Masmiyya_al-Saghira
# /wiki/Al-%27Ulmaniyya
# /wiki/1947%E2%80%931948_Civil_War_in_Mandatory_Palestine
# /wiki/Ain_es_Saheb_airstrike
# /wiki/Syrian_Social_Nationalist_Party
# /wiki/Lebanese_National_Movement
# /wiki/Maronite_Christianity_in_Lebanon
# /wiki/Elias_Sarkis
# /wiki/President_of_Lebanon
# /wiki/Gebran_Bassil
# /wiki/Kataeb_Regulatory_Forces
# /wiki/MG_34
# /wiki/Panzerfaust
# /wiki/Type_4_70_mm_AT_Rocket_Launcher
# /wiki/World_War_II
# /wiki/Invasion_of_the_Kuril_Islands
# /wiki/List_of_military_awards_and_decorations_of_World_War_II
# /wiki/Order_of_Alexander_Nevsky
# /wiki/Medal_of_Ushakov
# /wiki/Order_of_Suvorov
# /wiki/Medal_%22In_Commemoration_of_the_1000th_Anniversary_of_Kazan%22
# /wiki/Russian_language
# /wiki/Graffiti_in_Russia
# /wiki/Xenophobia
# /wiki/Anti-Italianism
# /wiki/Maxi_Trial
# /wiki/Pizzino
# /wiki/Corsican_mafia
# /wiki/Banda_della_Magliana
# /wiki/Magliana
# /wiki/Internal_migration
# /wiki/Columbus,_Ohio
# /wiki/Scioto_Lounge
# /wiki/James_W._Barney_Pickaweekee_Story_Grove
# /wiki/These_Are_My_Jewels
# /wiki/List_of_public_art_in_Columbus,_Ohio
# /wiki/Climate_of_Columbus,_Ohio
# /wiki/List_of_people_from_Columbus,_Ohio
# /wiki/Jack_Hanna
# /wiki/CBS
# /wiki/Smithsonian_Channel
# /wiki/MTV_Live_(TV_network)
# /wiki/VH1_Classic
# /wiki/Nick_Jr._(Turkish_TV_channel)
# /wiki/List_of_programs_broadcast_by_Nickelodeon_(Latin_America)
# /wiki/List_of_programs_broadcast_by_Discovery_Channel
# /wiki/Aaron_Kaufman
# /wiki/Stadium_Super_Trucks
# /wiki/Watkins_Glen_International
# /wiki/Riverside_International_Raceway
# /wiki/Watkins_Glen_International
# /wiki/Talladega_Superspeedway
# /wiki/Interstate_20
# /wiki/Interstate_15
# /wiki/Metropolitan_statistical_area
# /wiki/New_England_city_and_town_area
# /wiki/Hawaiian_home_land
# /wiki/Insular_area
# /wiki/Executive_Office_of_the_President_of_the_United_States
# /wiki/United_States_Bill_of_Rights
# /wiki/History_of_the_United_States_Constitution
# /wiki/Virginia
# /wiki/Appalachian_Plateau
# /wiki/United_States_House_of_Representatives
# /wiki/Wealth_in_the_United_States
# /wiki/Race_and_ethnicity_in_the_United_States_Census
# /wiki/Chalon_people
# /wiki/Rumsen_people
# /wiki/List_of_Ohlone_villages#Monterey_Bay_Area
# /wiki/Mission_Santa_Clara
# /wiki/Clare_of_Assisi
# /wiki/Jesus
# /wiki/Chan_Buddhism
# /wiki/Japanese_Zen
# /wiki/Tolstoyan_movement
# /wiki/A_Letter_to_a_Hindu
# /wiki/Purna_Swaraj
# /wiki/Round_Table_Conference
# /wiki/Dayananda_Saraswati
# /wiki/Doi_(identifier)
# /wiki/ISO_15398
# /wiki/ISO/IEC_646
# /wiki/ASCII
# /wiki/X
# /wiki/M
# /wiki/NATO_spelling_alphabet
# /wiki/Phoenician_alphabet
# /wiki/Sogdian_alphabet
# /wiki/Leet
# /wiki/Spam_(electronic)
# /wiki/Video_game
# /wiki/Springer_Publishing
# /wiki/Demos_Medical_Publishing
# /wiki/Springer_Publishing
# /wiki/Violence_%26_Victims
# /wiki/Victimisation
# /wiki/Genetic_discrimination
# /wiki/Pandemic
# /wiki/Doi_(identifier)
# /wiki/ISO_8373
# /wiki/ISO_31000
# /wiki/Topic_map
# /wiki/ISBN_(identifier)
# /wiki/Grimoire
# /wiki/British_Empire
# /wiki/North_Sea_Empire
# /wiki/Ethnolinguistic_group
# /wiki/Semiotics
# /wiki/Social_semiotics
# /wiki/Decoding_(semiotics)
# /wiki/Kalevi_Kull
# /wiki/Louis_Hjelmslev
# /wiki/Modality_(semiotics)
# /wiki/Kalevi_Kull
# /wiki/Semiotics_of_culture
# /wiki/Cultural_technology
# /wiki/List_of_number-one_albums_in_South_Korea_(1998%E2%80%932008)
# /wiki/Koyote
# /wiki/Billboard_(magazine)
# /wiki/List_of_Billboard_Hot_100_number_ones_of_1987
# /wiki/Chicago_Tribune
# /wiki/Tabloid_(newspaper_format)
# /wiki/The_Oregonian
# /wiki/United_States_Democratic_Party
# /wiki/2020_United_States_presidential_election
# /wiki/Biden-Sanders_Unity_Task_Forces
# /wiki/List_of_Joe_Biden_2020_presidential_campaign_primary_endorsements
# /wiki/Rocky_De_La_Fuente
# /wiki/2018_United_States_Senate_election_in_Florida
# /wiki/Puerto_Rico
# /wiki/Pi%C3%B1a_colada
# /wiki/Stinger_(cocktail)
# /wiki/Irish_coffee
# /wiki/Negroni
# /wiki/Mint_julep
# /wiki/1894_Kentucky_Derby
# /wiki/1921_Kentucky_Derby
# /wiki/Kentucky_Derby
# /wiki/1900_Kentucky_Derby
# /wiki/1941_Kentucky_Derby
# /wiki/1942_Kentucky_Derby
# /wiki/2006_Kentucky_Derby
# /wiki/1928_Kentucky_Derby
# /wiki/1955_Kentucky_Derby
# /wiki/1900_Kentucky_Derby
# /wiki/2012_Kentucky_Derby
# /wiki/Woodward_Stakes
# /wiki/William_Ward_Stephens
# /wiki/Aqueduct_Racetrack
# /wiki/Carter_Handicap
# /wiki/Fair_Stable
# /wiki/New_York_City
# /wiki/Setback_(architecture)
# /wiki/United_States
# /wiki/Indentured_servitude
# /wiki/Slavery
# /wiki/Graduate_unemployment
# /wiki/Political_science
# /wiki/North_America
# /wiki/Eastern_Ghats
# /wiki/Remote_sensing
# /wiki/GRASS_GIS
# /wiki/Scientific_research
# /wiki/Transhumanism
# /wiki/Kevin_Warwick
# /wiki/Brain_implant
# /wiki/PlanetSide
# /wiki/Multiplayer_video_game
# /wiki/Boss_(video_games)
# /wiki/Power-up
# /wiki/Sonic_the_Hedgehog_series
# /wiki/GamesRadar%2B
# /wiki/HobbyConsolas
# /wiki/Mobile_device
# /wiki/Smartphone
# /wiki/Google_Chromium
# /wiki/Google_Health
# /wiki/Google_Questions_and_Answers
# /wiki/Google_Sidewiki
# /wiki/Reddit
# /wiki/CNBC
# /wiki/GolfNow
# /wiki/NBC_Weather_Plus
# /wiki/KCEN
# /wiki/Waco,_Texas
# /wiki/Boob_Fowler
# /wiki/Shortstop
# /wiki/Catcher
# /wiki/Center_fielder
# /wiki/Oscar_Charleston
# /wiki/Rogers_Hornsby
# /wiki/Fred_Clarke
# /wiki/Carlton_Fisk
# /wiki/George_Davis_(baseball)
# /wiki/Ken_Boyer
# /wiki/St._Louis_Cardinals_Hall_of_Fame_Museum
# /wiki/Chief_executive_officer
# /wiki/Chief_visionary_officer
# /wiki/Chief_research_officer
# /wiki/Management
# /wiki/Bureaucrat
# /wiki/Ancien_regime
# /wiki/Battle_of_Neerwinden_(1793)
# /wiki/Battle_of_Famars
# /wiki/Battle_of_Raismes_(1793)
# /wiki/Famars
# /wiki/Lambres-lez-Douai
# /wiki/Busigny
# /wiki/Camphin-en-P%C3%A9v%C3%A8le
# /wiki/Dimont
# /wiki/De%C3%BBl%C3%A9mont
# /wiki/Haut-Lieu
# /wiki/Villers-Pol
# /wiki/Les_Rues-des-Vignes
# /wiki/Bermerain
# /wiki/Halluin
# /wiki/Choisies
# /wiki/Semousies
# /wiki/Trith-Saint-L%C3%A9ger
# /wiki/Assevent
# /wiki/Maubeuge
# /wiki/Halluin
# /wiki/Volckerinckhove
# /wiki/Cobrieux
# /wiki/Lez-Fontaine
# /wiki/Godewaersvelde
# /wiki/Lille
# /wiki/BCG_vaccine
# /wiki/Middlebrook_7H9_Broth
# /wiki/Preventorium
# /wiki/Lakewood,_New_Jersey
# /wiki/At-large
# /wiki/California_Voting_Rights_Act
# /wiki/California_State_Senate
# /wiki/New_York_State_Senate
# /wiki/143rd_New_York_State_Legislature
# /wiki/Republican_Party_(United_States)
# /wiki/1994_United_States_House_of_Representatives_elections
# /wiki/1962_United_States_House_of_Representatives_elections_in_California
# /wiki/2018_California_Secretary_of_State_election
# /wiki/1996_California_State_Senate_election
# /wiki/2008_California_Proposition_7
# /wiki/1950_United_States_House_of_Representatives_elections_in_California
# /wiki/2014_San_Bernardino_mayoral_election
# /wiki/2008_California_Proposition_3
# /wiki/Federal_government_of_the_United_States
# /wiki/Article_Two_of_the_United_States_Constitution
# /wiki/Papal_election
# /wiki/Wayback_Machine
# /wiki/PetaBox
# /wiki/Internet_Archive#Moving_image_collection
# /wiki/Controlled_digital_lending
# /wiki/Weeding_(library)
# /wiki/Preservation_(library_and_archive)
# /wiki/Emergency_management
# /wiki/Perception_management
# /wiki/Fuwa
# /wiki/Yangshao_culture
# /wiki/Laurent_Sagart
# /wiki/ISSN_(identifier)
# /wiki/Renard_series
# /wiki/ISO_10303
# /wiki/ISO_11784_and_ISO_11785
# /wiki/ISO_7001
# /wiki/International_Standard_Book_Number
# /wiki/National_Library_of_the_Philippines
# /wiki/National_Library_of_Egypt
# /wiki/List_of_sovereign_states
# /wiki/Continent
# /wiki/Westphalia
# /wiki/Paderborn
# /wiki/W%C3%BCrzburg
# /wiki/Kiel
# /wiki/States_of_Germany
# /wiki/1984_West_German_presidential_election
# /wiki/Richard_von_Weizs%C3%A4cker
# /wiki/University_of_Duisburg-Essen
# /wiki/Indiana_University_of_Pennsylvania
# /wiki/IUP_Crimson_Hawks
# /wiki/800_metres
# /wiki/Confederation_of_African_Athletics
# /wiki/IAAF_Golden_League
# /wiki/2001_IAAF_Grand_Prix
# /wiki/Konstadinos_Gatsioudis
# /wiki/Athletics_at_the_1996_Summer_Olympics
# /wiki/Hungary_at_the_1996_Summer_Olympics
# /wiki/Angola_at_the_1996_Summer_Olympics
# /wiki/Angola_at_the_2000_Summer_Olympics
# /wiki/Angola_women%27s_national_handball_team
# /wiki/Tunisia_women%27s_national_handball_team
# /wiki/Republic_of_the_Congo
# /wiki/Politics_of_the_African_Union
# /wiki/2007_in_Africa
# /wiki/List_of_African_countries_by_Human_Development_Index
# /wiki/Scramble_for_Africa
# /wiki/Oreste_Baratieri
# /wiki/Giacomo_De_Martino_(governor)
# /wiki/Luigi_Frusci
# /wiki/Venosa
# /wiki/Noepoli
# /wiki/Griko
# /wiki/Crotone
# /wiki/Serie_A
# /wiki/Gianluigi_Buffon
# /wiki/World_Food_Programme
# /wiki/United_Nations_Global_Compact
# /wiki/International_Decade_for_a_Culture_of_Peace_and_Non-Violence_for_the_Children_of_the_World
# /wiki/International_observance
# /wiki/Inventors%27_Day
# /wiki/Entrepreneurs
# /wiki/Perspectives_on_capitalism_by_school_of_thought
# /wiki/Neo-Keynesian_economics
# /wiki/Economic_rent
# /wiki/Economic_planning
# /wiki/Owenism
# /wiki/Socialist-oriented_market_economy
# /wiki/Socialist_calculation_debate
# /wiki/Pyotr_Lavrov
# /wiki/Culture_of_Europe
# /wiki/Byzantine_silk
# /wiki/David
# /wiki/Typology_(theology)
# /wiki/Ezekiel
# /wiki/Fulgentius_of_Ruspe
# /wiki/Rome
# /wiki/Palmanova
# /wiki/Trivignano_Udinese
# /wiki/Zuglio
# /wiki/List_of_dialling_codes_in_Italy
# /wiki/La_Spezia
# /wiki/List_of_twin_towns_and_sister_cities_in_Italy
# /wiki/Acre,_Israel
# /wiki/Migdal_HaEmek
# /wiki/Rosh_Pinna
# /wiki/PMID_(identifier)
# /wiki/PMID_(identifier)
# /wiki/ZymoGenetics
# /wiki/Novo_Nordisk
# /wiki/Saxenda
# /wiki/Orexin
# /wiki/Hypocretin_(orexin)_receptor_1
# /wiki/Ensembl_genome_database_project
# /wiki/Worm
# /wiki/Arthropod
# /wiki/ISBN_(identifier)
# /wiki/Vicat_softening_point
# /wiki/ISO/IEC_8859-4
# /wiki/Code_page_874
# /wiki/%E2%80%94
# /wiki/Text_figures
# /wiki/Rotated_letter
# /wiki/Calligraphy
# /wiki/Syllabary
# /wiki/Gujarati_script
# /wiki/Breathy_voice
# /wiki/Modal_voice
# /wiki/Bass_(sound)
# /wiki/Upright_bass
# /wiki/George_Mraz
# /wiki/Mal_81
# /wiki/Speak,_Brother,_Speak!
# /wiki/Joe_Zawinul
# /wiki/Vienna_Central_Cemetery
# /wiki/Conservatism
# /wiki/Reaganomics
# /wiki/Natural_resource_economics
# /wiki/Environmental_policy
# /wiki/Ecology
# /wiki/Doi_(identifier)
# /wiki/Archival_Resource_Key
# /wiki/Info_URI_scheme
# /wiki/Internet_Engineering_Task_Force
# /wiki/List_of_Internet_phenomena
# /wiki/GIF
# /wiki/LZ77_and_LZ78
# /wiki/Portable_Network_Graphics
# /wiki/Container_format_(digital)
# /wiki/Peel_(software)
# /wiki/MacOS
# /wiki/Mac_OS_9
# /wiki/Macintosh_operating_systems
# /wiki/Apple_Worldwide_Developers_Conference
# /wiki/AirPort_Time_Capsule
# /wiki/Apple_AudioVision_14_Display
# /wiki/Apple_Silentype
# /wiki/Apple_AudioVision_14_Display
# /wiki/Power_Macintosh_9600
# /wiki/PowerBook_G3
# /wiki/Apple_II_serial_cards
# /wiki/Apple_displays
# /wiki/Hard_Disk_20
# /wiki/Macintosh_Classic
# /wiki/Macintosh_IIsi
# /wiki/Floating_point_unit
# /wiki/Power_management_integrated_circuit
# /wiki/Intersil
# /wiki/Milpitas,_California
# /wiki/Milpitas_Transit_Center
# /wiki/Cropley_station
# /wiki/Santa_Clara_County,_California
# /wiki/Oslo
# /wiki/%C3%85snes
# /wiki/Denmark
# /wiki/Wayback_Machine
# /wiki/Internet_as_a_source_of_prior_art
# /wiki/Novelty_(patent)
# /wiki/Case_Law_of_the_Boards_of_Appeal_of_the_European_Patent_Office
# /wiki/Limitation_and_revocation_procedures_before_the_European_Patent_Office
# /wiki/European_Round_Table_on_Patent_Practice
# /wiki/Malta
# /wiki/Economy_of_Guatemala
# /wiki/Economy_of_Mongolia
# /wiki/Soviet_Union
# /wiki/Karakalpak_Autonomous_Soviet_Socialist_Republic
# /wiki/Russian_language
# /wiki/Velarization
# /wiki/Danish_language
# /wiki/Swedish_language
# /wiki/Gustav_Vasa
# /wiki/G%C3%B6taland
# /wiki/Gunnebo_House
# /wiki/G%C3%B6teborgs_Konsthall
# /wiki/Gothenburg
# /wiki/Eurovision_Song_Contest_2013
# /wiki/Armenia_in_the_Eurovision_Song_Contest_2013
# /wiki/Denmark_in_the_Eurovision_Song_Contest_2013
# /wiki/Croatia_in_the_Eurovision_Song_Contest_2013
# /wiki/Jacques_Houdek
# /wiki/Zdravko_%C4%8Coli%C4%87
# /wiki/Hora_(dance)
# /wiki/Religious_Jewish_music
# /wiki/Kaddish
# /wiki/Psalm_136
# /wiki/Psalm_70
# /wiki/Psalm_119
# /wiki/Proverbs_1
# /wiki/Agur
# /wiki/Eliezer#Eliezer_the_prophet
# /wiki/Samuel
# /wiki/Patriarchs_(Bible)
# /wiki/Rachel
# /wiki/Religion_in_pre-Islamic_Arabia#Mecca
# /wiki/Al-Lat
# /wiki/Attar_(god)
# /wiki/Aramaic
# /wiki/Samaritan_Aramaic_language
# /wiki/Judeo-Marathi
# /wiki/Lish%C3%A1n_Did%C3%A1n
# /wiki/Judaeo-Piedmontese
# /wiki/Spanish_dialects_and_varieties
# /wiki/Bolivian_Spanish
# /wiki/Costa_Rican_Spanish
# /wiki/Ecuadorian_Spanish
# /wiki/Canarian_Spanish
# /wiki/Teide
# /wiki/Soil
# /wiki/Cation
# /wiki/Flow_battery
# /wiki/S2CID_(identifier)
# /wiki/Collection_of_articles
# /wiki/Public_health_journal
# /wiki/SCImago_Journal_Rank
# /wiki/Pamphlet
# /wiki/Middle_English
# /wiki/Klezmer-loshn
# /wiki/Argot
# /wiki/Welsh_phonology
# /wiki/Upper_Sorbian_phonology
# /wiki/Voiced_alveolar_trill
# /wiki/IPA_vowel_chart_with_audio
# /wiki/Velar_consonant
# /wiki/Pirah%C3%A3_language
# /wiki/Fricative_consonant
# /wiki/Implosive_consonant
# /wiki/Labial%E2%80%93coronal_consonant
# /wiki/Palatalization_(phonetics)
# /wiki/Speech_pathology
# /wiki/Separation_anxiety_disorder
# /wiki/Physical_dependence
# /wiki/Zopiclone
# /wiki/ISSN_(identifier)
# /wiki/PDF
# /wiki/Comparison_of_notetaking_software
# /wiki/ConnectedText
# /wiki/Microsoft_Windows
# /wiki/Windows_Ultimate_Extras
# /wiki/Reversi
# /wiki/Japan
# /wiki/ISBN_(identifier)
# /wiki/ISO_11940
# /wiki/FDI_World_Dental_Federation_notation
# /wiki/Film_speed
# /wiki/Ada_Semantic_Interface_Specification
# /wiki/Document_Style_Semantics_and_Specification_Language
# /wiki/Object_Constraint_Language
# /wiki/ISO_15926
# /wiki/Upstream_(oil_industry)
# /wiki/Oil_shale_gas
# /wiki/Natural_gas
# /wiki/Methane_emissions
# /wiki/NASA_JPL
# /wiki/ISNI_(identifier)
# /wiki/ISO_22395
# /wiki/ISO_13490
# /wiki/ISO_128
# /wiki/Photographic_Activity_Test
# /wiki/Adhesive
# /wiki/Marquetry
# /wiki/Fore_plane
# /wiki/Hazel
# /wiki/Halved_joint
# /wiki/Root_carving
# /wiki/Sawdust
# /wiki/Timber_roof_truss
# /wiki/Biomass
# /wiki/Choker_setter
# /wiki/Rubber_tapping
# /wiki/Cocoa_bean
# /wiki/Store_of_value
# /wiki/Oligopsony
# /wiki/Cartel
# /wiki/Kingdom_of_France_(987%E2%80%931498)
# /wiki/John_of_England
# /wiki/Duchy_of_Normandy
# /wiki/Chamavi
# /wiki/Ethnolinguistic_group
# /wiki/Internet_linguistics
# /wiki/Virtual_worlds
# /wiki/Immersion_(virtual_reality)#Presence
# /wiki/ISSN_(identifier)
# /wiki/EAN-13
# /wiki/Boxing_barcode
# /wiki/Plessey_Code
# /wiki/Object_hyperlinking
# /wiki/Location-based_service
# /wiki/European_GNSS_Agency
# /wiki/NASA_Authorization_Act_of_2010
# /wiki/Aeronautics
# /wiki/Aviation
# /wiki/Lakehurst_Naval_Air_Station
# /wiki/United_States_Naval_Observatory
# /wiki/Network_Time_Protocol
# /wiki/Ubuntu_(operating_system)
# /wiki/Ubuntu_version_history#2004
# /wiki/Code_name
# /wiki/German_language
# /wiki/Amelands
# /wiki/Terschelling
# /wiki/Vlieland
# /wiki/De_Cocksdorp
# /wiki/Den_Burg
# /wiki/Hans_Kamp
# /wiki/Linguistics
# /wiki/Morphology_(linguistics)
# /wiki/Noun_phrase
# /wiki/Finite_clause
# /wiki/Predicative_expression
# /wiki/Tabasaran_language
# /wiki/Samur_languages
# /wiki/Budukh_language
# /wiki/Ingush_language
# /wiki/Kazakhstan
# /wiki/Wayback_Machine
# /wiki/Internet_Memory_Foundation
# /wiki/Future_Internet_Research_and_Experimentation
# /wiki/Future_Internet
# /wiki/Internet
# /wiki/Wiley_(publisher)
# /wiki/U.S._Environmental_Protection_Agency
# /wiki/Clean_Air_Act_of_1963
# /wiki/John_F._Kennedy_Center_for_the_Performing_Arts
# /wiki/Ragtime_(musical)
# /wiki/Come_from_Away
# /wiki/Diverted
# /wiki/IMDb
# /wiki/TenMarks_Education,_Inc.
# /wiki/Amazon_Fresh
# /wiki/Purity_Supreme
# /wiki/Tops_Friendly_Markets
# /wiki/New_York_(state)
# /wiki/List_of_New_York_state_parks
# /wiki/Old_Croton_Aqueduct_State_Historic_Park
# /wiki/Finger_Lakes_Trail
# /wiki/New_York_State_Department_of_Environmental_Conservation
# /wiki/Nassau_County,_New_York
# /wiki/East_Williston,_New_York
# /wiki/1960_United_States_census
# /wiki/Ohio
# /wiki/Greater_Cleveland
# /wiki/Lake_Erie
# /wiki/Avon_Lake,_Ohio
# /wiki/1920_United_States_census
# /wiki/Peoria,_Illinois
# /wiki/Rockford_metropolitan_area,_Illinois
# /wiki/Springfield,_Illinois
# /wiki/List_of_capitals_in_the_United_States
# /wiki/Irreligion_in_the_United_States#Demographics
# /wiki/Lists_of_United_States_state_prisons
# /wiki/List_of_Rhode_Island_state_prisons
# /wiki/Cranston,_Rhode_Island
# /wiki/Bristol_County,_Rhode_Island
# /wiki/1936_United_States_presidential_election_in_Rhode_Island
# /wiki/1787_Rhode_Island_gubernatorial_election
# /wiki/1896_Rhode_Island_gubernatorial_election
# /wiki/1835_United_States_House_of_Representatives_election_in_Rhode_Island
# /wiki/Plural_district
# /wiki/Huntington%E2%80%93Hill_method
# /wiki/Tideman_alternative_method
# /wiki/Bucklin_voting
# /wiki/Members_of_the_San_Francisco_Board_of_Supervisors#endnote_PreferentialVoteE
# /wiki/Dolores_Park
# /wiki/Lists_of_San_Francisco_topics
# /wiki/List_of_San_Francisco_49ers_seasons
# /wiki/List_of_Green_Bay_Packers_seasons
# /wiki/1992_Green_Bay_Packers_season
# /wiki/David_Viaene
# /wiki/Houston_Oilers
# /wiki/Houston_Astrodome
# /wiki/Route_66_Raceway
# /wiki/Terre_Haute_Action_Track
# /wiki/Mansfield_Motor_Speedway
# /wiki/Huntsville_Speedway
# /wiki/Road_racing
# /wiki/Riverside_International_Raceway
# /wiki/Roy_Hord_Jr.
# /wiki/Philadelphia_Eagles
# /wiki/Michael_Clay
# /wiki/Undrafted_free_agent
# /wiki/Transfer_window
# /wiki/FIFA
# /wiki/FIFA_U-17_World_Cup
# /wiki/1997_FIFA_U-17_World_Championship_squads
# /wiki/Forward_(association_football)
# /wiki/Kit_(association_football)
# /wiki/Assistant_referee_(association_football)
# /wiki/Penalty_area
# /wiki/Nutmeg_(association_football)
# /wiki/List_of_CONCACAF_national_association_football_teams_by_nickname
# /wiki/Flip_flap_(association_football)
# /wiki/Association_football_tactics_and_skills
# /wiki/Roberto_Rivelino
# /wiki/Shimizu_S-Pulse
# /wiki/Ryo_Okui
# /wiki/FIFA
# /wiki/Croatia_national_football_team
# /wiki/Belgium_national_football_team
# /wiki/Jean_Thissen
# /wiki/Georg_Ke%C3%9Fler
# /wiki/Louis_Pilot
# /wiki/Marie_Muller
# /wiki/Ni_Xialian
# /wiki/Taeko_Namba
# /wiki/2013_World_Table_Tennis_Championships
# /wiki/Chinese_Taipei
# /wiki/United_Nations_Department_of_Economic_and_Social_Affairs
# /wiki/United_Nations_High_Commissioner_for_Refugees
# /wiki/Refugee
# /wiki/Boston_University
# /wiki/Lelia_J._Robinson
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_14443
# /wiki/Antimagnetic_watch
# /wiki/TIFF/EP
# /wiki/Longitudinal_redundancy_check
# /wiki/ISO_5428
# /wiki/Mazovia_encoding
# /wiki/Code_page_1038
# /wiki/Bodoni
# /wiki/Optima
# /wiki/Erbar_(typeface)
# /wiki/Monotype_Imaging
# /wiki/Solus_(typeface)
# /wiki/Gwendolin_(typeface)
# /wiki/Senedd_building
# /wiki/Alun_Michael
# /wiki/VIAF_(identifier)
# /wiki/OCLC
# /wiki/OCLC_(identifier)
# /wiki/Wikimedia_Foundation
# /wiki/Vinod_Khosla
# /wiki/Los_Angeles_Times
# /wiki/The_Miami_News
# /wiki/WFOX-TV
# /wiki/Jacksonville,_Florida
# /wiki/69_Boyz
# /wiki/Miami_bass
# /wiki/Ragga_hip_hop
# /wiki/Belgian_hip_hop
# /wiki/Hip-hop_theater
# /wiki/Thai_hip_hop
# /wiki/Hip_hop_soul
# /wiki/Sean_%22Puffy%22_Combs
# /wiki/The_Hollywood_Reporter
# /wiki/Tichi_Wilkerson_Kassel
# /wiki/List_of_stars_on_the_Hollywood_Walk_of_Fame
# /wiki/Dick_Haynes
# /wiki/Tennessee_Champ
# /wiki/Metro-Goldwyn-Mayer
# /wiki/Providence_Equity_Partners
# /wiki/Bloomberg_Businessweek
# /wiki/2001_New_York_City_mayoral_election
# /wiki/2013_New_York_City_mayoral_election
# /wiki/1918_New_York_gubernatorial_election
# /wiki/1918_United_States_House_of_Representatives_election_in_Arizona
# /wiki/Thomas_U._Sisson
# /wiki/Mississippi%27s_4th_congressional_district
# /wiki/51st_United_States_Congress
# /wiki/Levi_Maish
# /wiki/Manchester_Township,_York_County,_Pennsylvania
# /wiki/National_Register_of_Historic_Places
# /wiki/Storrs,_Connecticut
# /wiki/New_Britain,_Connecticut
# /wiki/Greater_Bridgeport
# /wiki/Plymouth,_Connecticut
# /wiki/West_Haven,_Connecticut
# /wiki/Colonial_history_of_the_United_States
# /wiki/JSTOR_(identifier)
# /wiki/Academic_community
# /wiki/Hellenistic
# /wiki/Strategos
# /wiki/Classical_Athens
# /wiki/Toxotai
# /wiki/Archerfish
# /wiki/Tan_Heok_Hui
# /wiki/Habitats
# /wiki/ISBN_(identifier)
# /wiki/OSI_model
# /wiki/ISO_26000
# /wiki/ISO_37001
# /wiki/Group_of_States_Against_Corruption
# /wiki/Council_of_Europe
# /wiki/Pope_Francis
# /wiki/Catholic_Church
# /wiki/Offertory
# /wiki/Church_etiquette
# /wiki/Methodist
# /wiki/Protestant_Reformation
# /wiki/Anabaptist
# /wiki/East%E2%80%93West_Schism
# /wiki/Paschal_Homily
# /wiki/Reform_of_the_date_of_Easter
# /wiki/World_Council_of_Churches
# /wiki/Evangelical_Presbyterian_Church_in_England_and_Wales
# /wiki/Welsh_language
# /wiki/Object_(grammar)
# /wiki/Syntactic_category
# /wiki/Lexical_category
# /wiki/Morphology_(linguistics)
# /wiki/Morphological_typology
# /wiki/Afrikaans
# /wiki/Danish_language
# /wiki/Greenland
# /wiki/Physical_geography
# /wiki/Health_geography
# /wiki/London
# /wiki/Bermondsey
# /wiki/Spa_Road_railway_station
# /wiki/Broad_Street_railway_station_(London)
# /wiki/Broad_Street_railway_station_(London)
# /wiki/Goods_station
# /wiki/Linz
# /wiki/Dependent_territory
# /wiki/Superstate
# /wiki/Anarchism
# /wiki/Bavarian_Soviet_Republic
# /wiki/Free_City_of_L%C3%BCbeck
# /wiki/Continental_System
# /wiki/Confederation_of_the_Rhine
# /wiki/Holy_Roman_Empire
# /wiki/ISBN_(identifier)
# /wiki/Malta
# /wiki/India
# /wiki/Shaivism
# /wiki/Shakti
# /wiki/Uttarakhand
# /wiki/Haridwar_Kumbh_Mela
# /wiki/Halwai
# /wiki/Hindi_language
# /wiki/Jammu_and_Kashmir_(union_territory)
# /wiki/Downtown_Srinagar
# /wiki/Rajouri
# /wiki/Chenani
# /wiki/Ranbir_Singh_Pora
# /wiki/Census
# /wiki/Simultaneous_equations_model
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_base_media_file_format
# /wiki/Motion_JPEG
# /wiki/Moving_Picture_Experts_Group
# /wiki/Versatile_Video_Coding
# /wiki/FDI_World_Dental_Federation_notation
# /wiki/ISO_10006
# /wiki/ISO_21500
# /wiki/Standard_Generalized_Markup_Language
# /wiki/ISO_31-12
# /wiki/MPEG-4_Part_14
# /wiki/ISO_12620
# /wiki/ISO_13485
# /wiki/ISO_657
# /wiki/ISO/IEC_8859-9
# /wiki/Code_page_1133
# /wiki/Code_page_950
# /wiki/KS_X_1002
# /wiki/Prosigns_for_Morse_code
# /wiki/Kana
# /wiki/Bengali_Braille
# /wiki/Vibratese
# /wiki/Kulitan
# /wiki/Bamum_script
# /wiki/Bamum_language
# /wiki/Jigawa_State
# /wiki/Malam_Madori
# /wiki/Biriniwa
# /wiki/Gagarawa
# /wiki/Jahun
# /wiki/Kaugama
# /wiki/Dutse
# /wiki/Okene
# /wiki/Adavi,_Nigeria
# /wiki/Nigeria
# /wiki/Tiv_people
# /wiki/Dwe%27e_people
# /wiki/Kwasio_people
# /wiki/Ndowe
# /wiki/Pygmy_peoples
# /wiki/American_University
# /wiki/Adnan_Khashoggi
# /wiki/Lockheed_bribery_scandals
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_7812
# /wiki/ISO/IEC_19752
# /wiki/Topic_map
# /wiki/ANSI_C
# /wiki/Operators_in_C_and_C%2B%2B
# /wiki/Increment_and_decrement_operators
# /wiki/B_(programming_language)
# /wiki/Fortran
# /wiki/History_of_compiler_writing
# /wiki/Jacob_T._Schwartz
# /wiki/Programming_language
# /wiki/Haskell_(programming_language)
# /wiki/Facebook
# /wiki/Application_software
# /wiki/Platform_as_a_service
# /wiki/Box_(company)
# /wiki/Tresorit
# /wiki/IDisk
# /wiki/OneDrive
# /wiki/Print_Services_for_UNIX
# /wiki/Groove_Music
# /wiki/Task_View
# /wiki/Cardfile
# /wiki/Task_Manager_(Windows)
# /wiki/Microsoft_Tips
# /wiki/Computer_program
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_17025
# /wiki/ISO_15926_WIP
# /wiki/ISO/IEC_17025
# /wiki/Unified_Modeling_Language
# /wiki/Portable_Document_Format
# /wiki/Google_Play_Books
# /wiki/Vevo
# /wiki/Reply_(Google)
# /wiki/The_Verge
# /wiki/Money,_Explained
# /wiki/October_Faction_(TV_series)
# /wiki/The_Trials_of_Gabriel_Fernandez
# /wiki/Decider_(website)
# /wiki/James_Alexander_Hamilton
# /wiki/Hamilton_Hall_(Salem,_Massachusetts)
# /wiki/National_Register_of_Historic_Places_listings_in_Marlborough,_Massachusetts
# /wiki/Keeper_of_the_Register
# /wiki/American_Legation,_Tangier
# /wiki/American_School_of_Tangier
# /wiki/Instituto_Espa%C3%B1ol_Melchor_de_Jovellanos
# /wiki/Morocco
# /wiki/Italy
# /wiki/Province_of_Gorizia
# /wiki/Friuli%E2%80%93Venezia_Giulia
# /wiki/Provinces_of_Italy
# /wiki/Rieti
# /wiki/Lower_Saxony
# /wiki/Catholicism
# /wiki/Early_centers_of_Christianity
# /wiki/Periyar_River
# /wiki/Perennial_stream
# /wiki/Riparian-zone_restoration
# /wiki/Biodiversity
# /wiki/Exponential_growth
# /wiki/Orders_of_magnitude_(numbers)#1027
# /wiki/Judaism
# /wiki/Yom_Ha-shoah
# /wiki/Kamianets-Podilskyi_massacre
# /wiki/Sbarro_restaurant_suicide_bombing
# /wiki/2000%E2%80%9306_Shebaa_Farms_conflict
# /wiki/Israel%27s_role_in_the_Iran%E2%80%93Iraq_war
# /wiki/ISSN_(identifier)
# /wiki/Graphical_Kernel_System
# /wiki/IEC_60027
# /wiki/ISO/IEC_27000-series
# /wiki/RM-ODP
# /wiki/Distributed_systems
# /wiki/Parallel_programming_model
# /wiki/OpenCL
# /wiki/Maxwell_(microarchitecture)
# /wiki/Nvidia_Tesla
# /wiki/GeForce_9_series
# /wiki/8800GT
# /wiki/PureVideo
# /wiki/Nouveau_(software)
# /wiki/Computer-aided_design
# /wiki/Drug_design
# /wiki/Adaptive_web_design
# /wiki/New_product_development
# /wiki/Design_closure
# /wiki/Floral_design
# /wiki/Ecological_design
# /wiki/Mind_map
# /wiki/Araucaria_(software)
# /wiki/Toulmin_model
# /wiki/Scientific_law
# /wiki/Uniformitarianism
# /wiki/Geology
# /wiki/Sea_level
# /wiki/Tidal_race
# /wiki/Offshore_survey
# /wiki/Cl%C3%A1udio_Coutinho
# /wiki/Haenyeo
# /wiki/Andrew_Wight
# /wiki/Gary_Gentile
# /wiki/Bathysphere
# /wiki/American_Museum_of_Natural_History
# /wiki/W._Douglas_Burden
# /wiki/The_New_York_Times
# /wiki/Pulitzer_Prize_for_Explanatory_Reporting
# /wiki/1920_Pulitzer_Prize
# /wiki/1952_Pulitzer_Prize
# /wiki/Joseph_Kramm
# /wiki/John_Patrick_Shanley
# /wiki/Nicolas_Cage
# /wiki/Marc_Coppola_(actor)
# /wiki/Christopher_Coppola
# /wiki/Toronto_International_Film_Festival
# /wiki/Government_of_Ontario
# /wiki/Public_Health_Ontario
# /wiki/Ministry_of_Heritage,_Sport,_Tourism_and_Culture_Industries_(Ontario)
# /wiki/Ministry_of_Economic_Development_(Ontario)
# /wiki/Royal_Ontario_Museum
# /wiki/Zoboomafoo
# /wiki/Jay_Jay_the_Jet_Plane
# /wiki/PBS_Kids
# /wiki/WXXI-TV
# /wiki/World_(TV_channel)
# /wiki/Boise_State_Public_Radio
# /wiki/CSN_International
# /wiki/Sheridan,_Wyoming
# /wiki/Riverton,_Wyoming
# /wiki/Solar_eclipse
# /wiki/Solar_Saros_149
# /wiki/Solar_eclipse_of_July_12,_2094
# /wiki/Solar_eclipse_of_March_29,_2025
# /wiki/Solar_eclipse_of_August_31,_1970
# /wiki/Solar_eclipse_of_January_16,_1972
# /wiki/Solar_eclipse_of_November_1,_1929
# /wiki/List_of_solar_eclipses_in_the_21st_century
# /wiki/Solar_eclipse_of_April_18,_1931
# /wiki/Solar_eclipse_of_September_11,_1969
# /wiki/Solar_eclipse_of_June_29,_1946
# /wiki/Solar_eclipse_of_January_27,_2055
# /wiki/Solar_eclipse_of_April_20,_2023
# /wiki/Assyrian_eclipse
# /wiki/Solar_eclipse_of_April_8,_1652
# /wiki/Solar_eclipse_of_June_16,_2178
# /wiki/Solar_eclipse_of_July_1,_2057
# /wiki/Solar_eclipse_of_May_29,_1938
# /wiki/Solar_eclipse
# /wiki/Solar_Saros_130
# /wiki/Solar_eclipse_of_July_20,_1944
# /wiki/Solar_eclipse_of_July_9,_1926
# /wiki/Saros_(astronomy)
# /wiki/April_2013_lunar_eclipse
# /wiki/April_2051_lunar_eclipse
# /wiki/September_2025_lunar_eclipse
# /wiki/Lunar_Saros_145
# /wiki/November_2041_lunar_eclipse
# /wiki/May_2022_lunar_eclipse
# /wiki/May_1976_lunar_eclipse
# /wiki/Solar_eclipse_of_May_19,_1985
# /wiki/Solar_Saros_154
# /wiki/Solar_eclipse_of_February_25,_1952
# /wiki/Solar_eclipse_of_November_3,_2013
# /wiki/Solar_eclipse_of_September_21,_2025
# /wiki/Solar_eclipse_of_August_10,_1934
# /wiki/Solar_Saros_125
# /wiki/Solar_eclipse_of_April_17,_1912
# /wiki/Solar_eclipse_of_November_15,_2077
# /wiki/Saros_(astronomy)
# /wiki/New_moon
# /wiki/Tidal_range
# /wiki/Edge_wave
# /wiki/Loop_Current
# /wiki/Equatorial_Counter_Current
# /wiki/North_Pacific_Gyre
# /wiki/Cape_Horn_Current
# /wiki/North_Brazil_Current
# /wiki/Canary_Current
# /wiki/Essaouira
# /wiki/Marsala
# /wiki/Trapani
# /wiki/M%C3%A1laga
# /wiki/Immigrants
# /wiki/Immigration_to_the_Czech_Republic
# /wiki/Vietnam
# /wiki/2018_AFF_Championship
# /wiki/Mandalay
# /wiki/Amarapura
# /wiki/Kyaukse
# /wiki/Geographic_coordinate_system
# /wiki/105th_meridian_west
# /wiki/40th_meridian_east
# /wiki/30th_meridian_west
# /wiki/175th_meridian_west
# /wiki/25th_meridian_west
# /wiki/75th_meridian_east
# /wiki/Karnataka
# /wiki/Robin_Uthappa
# /wiki/United_Arab_Emirates
# /wiki/Kurdistan_Region
# /wiki/Wayback_Machine
# /wiki/Hearsay
# /wiki/Criminal_law
# /wiki/Search_and_seizure
# /wiki/United_States_Reports
# /wiki/Reporter_of_Decisions_of_the_Supreme_Court_of_the_United_States#List_of_Reporters
# /wiki/Demographics_of_the_Supreme_Court_of_the_United_States
# /wiki/Supreme_Court_Police
# /wiki/United_States_Department_of_Commerce
# /wiki/Federal_Aviation_Administration
# /wiki/Federal_Motor_Carrier_Safety_Administration
# /wiki/Werner_Enterprises
# /wiki/Ticker_symbol
# /wiki/Unilever
# /wiki/Cleaning_agent
# /wiki/Orthophosphate
# /wiki/Anion
# /wiki/Actinide_chemistry
# /wiki/Quantum_chemistry
# /wiki/Path_integral_formulation
# /wiki/Interpretation_of_quantum_mechanics
# /wiki/S2CID_(identifier)
# /wiki/Google_Scholar
# /wiki/Chemical_patent
# /wiki/Academic_journal_publishing_reform
# /wiki/Okular
# /wiki/Internet_Archive
# /wiki/MusicBrainz
# /wiki/Open_data
# /wiki/Open_government
# /wiki/Carnegie_Endowment_for_International_Peace
# /wiki/Bharti_Enterprises
# /wiki/Real_estate
# /wiki/Housing
# /wiki/Housing_in_Japan
# /wiki/Tatami
# /wiki/Jinmaku
# /wiki/Sanmon
# /wiki/Ken_(unit)
# /wiki/Main_Hall_(Japanese_Buddhism)
# /wiki/Sand%C5%8D
# /wiki/Gohonzon
# /wiki/Bodhisattva
# /wiki/Mahayana
# /wiki/Moravian_Church
# /wiki/Pietist
# /wiki/Rostock
# /wiki/St._Mary%27s_Church,_Rostock
# /wiki/Geographic_coordinate_system
# /wiki/Tropic_of_Cancer
# /wiki/Nicholas_Channel
# /wiki/Straits_of_Florida
# /wiki/Strait
# /wiki/Hapua
# /wiki/Avulsion_(river)
# /wiki/Peninsula
# /wiki/Landform
# /wiki/Lijiang_River
# /wiki/Elephant_Trunk_Hill
# /wiki/Geographic_coordinate_system
# /wiki/Latitude
# /wiki/Lambert_cylindrical_equal-area_projection
# /wiki/Wagner_VI_projection
# /wiki/Map_projection#Pseudocylindrical
# /wiki/Geovisualization
# /wiki/Crime_mapping
# /wiki/Manuel_Lima
# /wiki/FRSA
# /wiki/England
# /wiki/National_emblem
# /wiki/List_of_national_trees
# /wiki/Tabebuia_chrysantha
# /wiki/Flowering_plant
# /wiki/Rosette_(botany)
# /wiki/Internode_(botany)
# /wiki/Herbarium
# /wiki/Stamen
# /wiki/Self-pollination
# /wiki/Microsporangia
# /wiki/Selaginella
# /wiki/EPPO_Code
# /wiki/Encoding
# /wiki/SECAM
# /wiki/Eastern_bloc
# /wiki/Socialism_in_one_country
# /wiki/Gonchigiin_Bumtsend
# /wiki/Mongolia
# /wiki/Hohhot
# /wiki/Bengbu
# /wiki/Anhui_Agricultural_University
# /wiki/Huangshan_University
# /wiki/University_of_Science_and_Technology_of_China
# /wiki/Qian_Xuesen
# /wiki/Yang_Xiufeng
# /wiki/Sun_Xiaocun
# /wiki/Edmund_Ho
# /wiki/Chen_Kuiyuan
# /wiki/Li_Keqiang
# /wiki/COVID-19_pandemic_in_Bulgaria
# /wiki/New_Zealand_government_response_to_the_COVID-19_pandemic
# /wiki/Stuff_(website)
# /wiki/The_Dominion_Post_(Wellington)
# /wiki/Otago_Witness
# /wiki/List_of_print_media_in_New_Zealand#Weeklies
# /wiki/Whanganui
# /wiki/New_Plymouth_Express
# /wiki/NZR_RM_class_(Silver_Fern)
# /wiki/Toshiba
# /wiki/Naval_mine
# /wiki/Explosive
# /wiki/Danubit
# /wiki/Slovakia
# /wiki/Zuzana_%C4%8Caputov%C3%A1
# /wiki/Goldman_Environmental_Prize
# /wiki/Jacqueline_Evans_(conservationist)
# /wiki/University_of_Hawaii_at_Manoa
# /wiki/Daniel_K._Inouye_International_Airport
# /wiki/Kansai_International_Airport
# /wiki/Tianjin_Binhai_International_Airport
# /wiki/Garze_Gesar_Airport
# /wiki/Lishui_Airport
# /wiki/Xi%27an_Xiguan_Airport
# /wiki/Xi%27an_Xianyang_International_Airport
# /wiki/Chizhou_Jiuhuashan_Airport
# /wiki/Chongqing_Baishiyi_Airport
# /wiki/Hanzhong_Xiguan_Airport
# /wiki/Yibin_Wuliangye_Airport
# /wiki/Haikou_Meilan_International_Airport
# /wiki/Baotou_Donghe_Airport
# /wiki/Zhengzhou_Xinzheng_International_Airport
# /wiki/Beijing_Capital_International_Airport
# /wiki/Chongqing_Xiann%C3%BCshan_Airport
# /wiki/IATA_airport_code
# /wiki/Omsukchan_Airport
# /wiki/Magadan_Oblast
# /wiki/Belgorod_Oblast
# /wiki/Yakovlevsky_District,_Belgorod_Oblast
# /wiki/Pyatnitskoye,_Belgorod_Oblast
# /wiki/Korochansky_District
# /wiki/Rakitnoye,_Belgorod_Oblast
# /wiki/Time_zone
# /wiki/Time_in_Sri_Lanka
# /wiki/Time_in_Cambodia
# /wiki/Time_in_Turkey
# /wiki/Daylight_saving_time
# /wiki/IERS_Reference_Meridian
# /wiki/Tema
# /wiki/Ashanti_Region
# /wiki/Ashanti_Empire
# /wiki/Sub-Saharan_Africa
# /wiki/Chinese_exploration
# /wiki/Taiwan
# /wiki/Cross-Strait_Service_Trade_Agreement
# /wiki/Xi_Jinping
# /wiki/Oxford_University_Press
# /wiki/Greys_Court
# /wiki/Stonor_Park
# /wiki/Abingdon_County_Hall_Museum
# /wiki/Soldiers_of_Oxfordshire_Museum
# /wiki/Oxford_Castle
# /wiki/Mapledurham_Watermill
# /wiki/Vale_and_Downland_Museum
# /wiki/Oxford_Bus_Museum
# /wiki/Morris_Oxford_bullnose
# /wiki/Lucas_Industries
# /wiki/GKN
# /wiki/Buses_(magazine)
# /wiki/British_Motor_Museum
# /wiki/Ascari_KZ1
# /wiki/BMW
# /wiki/BMW_R1200C
# /wiki/BMW_HP2_Enduro
# /wiki/BMW_K1200RS
# /wiki/Spandau
# /wiki/Steglitz
# /wiki/Wandervogel
# /wiki/Steglitz
# /wiki/Walther-Schreiber-Platz_(Berlin_U-Bahn)
# /wiki/Turmstra%C3%9Fe_(Berlin_U-Bahn)
# /wiki/Leinestra%C3%9Fe_(Berlin_U-Bahn)
# /wiki/Verkehrsverbund_Berlin-Brandenburg
# /wiki/Prignitzer_Eisenbahn
# /wiki/Mainz
# /wiki/Oceanic_climate
# /wiki/Humid_continental_climate
# /wiki/Tropical_climate
# /wiki/Tropical_savanna_climate
# /wiki/South_America
# /wiki/Loess_Plateau
# /wiki/Land_degradation
# /wiki/Water_conflict
# /wiki/Water_stress
# /wiki/Slash_and_burn
# /wiki/Cremation
# /wiki/Famine
# /wiki/Crop_failure
# /wiki/Hay
# /wiki/Redtop_grass
# /wiki/Poales
# /wiki/Trochodendraceae
# /wiki/Cornales
# /wiki/Johann_Heinrich_Friedrich_Link
# /wiki/Hildesheim
# /wiki/Harsum
# /wiki/MBAREA_(identifier)
# /wiki/Pitch_class
# /wiki/Equal_temperament
# /wiki/Just_intonation
# /wiki/Parallel_key
# /wiki/Key_signature_names_and_translations
# /wiki/Hindi
# /wiki/N%C4%81gar%C4%AB_script
# /wiki/Younger_Futhark
# /wiki/Shan_script
# /wiki/Tifinagh
# /wiki/Chinese_family_of_scripts
# /wiki/Romanian_Braille
# /wiki/American_Braille
# /wiki/Yugoslav_Braille
# /wiki/L
# /wiki/U
# /wiki/%E1%B4%9D
# /wiki/Eemil_Nestor_Set%C3%A4l%C3%A4
# /wiki/Hugo_Suolahti
# /wiki/Ville_It%C3%A4l%C3%A4
# /wiki/Harri_Holkeri
# /wiki/Pertti_Paasio
# /wiki/Finland
# /wiki/Sub-replacement_fertility
# /wiki/Emigration
# /wiki/Qing_Dynasty
# /wiki/High_Qing_era
# /wiki/Fuling_Mausoleum
# /wiki/Red_Lanterns_(Boxer_Uprising)
# /wiki/Grand_coordinator_and_provincial_governor
# /wiki/Vietnamese_Martyrs#The_Nguyen_Campaign_against_Catholicism_in_the_19th_century
# /wiki/Provincial_military_commander
# /wiki/Late_Qing_reforms
# /wiki/Taiwan_under_Qing_rule
# /wiki/History_of_Taiwan_(1945%E2%80%93present)
# /wiki/Telecommunications_in_Taiwan
# /wiki/Internet_censorship_in_Vietnam
# /wiki/Telecommunications_in_Cameroon#Internet_censorship_and_surveillance
# /wiki/Telegraphy
# /wiki/Gutta-percha
# /wiki/Peat
# /wiki/Pore_water_pressure
# /wiki/ISBN_(identifier)
# /wiki/ISO_5964
# /wiki/ISO_31-4
# /wiki/Film_speed
# /wiki/Fujicolor_Pro
# /wiki/Color_temperature
# /wiki/Tripod_head
# /wiki/Still_camera
# /wiki/Zebra_patterning
# /wiki/Stopping_down
# /wiki/Lead_room
# /wiki/List_of_photographic_equipment_makers
# /wiki/Photogram
# /wiki/Christian_Schad
# /wiki/Upper_Bavaria
# /wiki/Neuburg-Schrobenhausen
# /wiki/Kitzingen_(district)
# /wiki/Central_European_Time
# /wiki/Time_in_Malta
# /wiki/Time_in_San_Marino
# /wiki/Time_in_Albania
# /wiki/Moscow_Time
# /wiki/Crimea
# /wiki/Georgian_Bay
# /wiki/Niagara_Escarpment
# /wiki/Great_Lakes_Basin
# /wiki/North_Channel_(Ontario)
# /wiki/St._Lawrence_Seaway
# /wiki/L%C3%A9vis,_Quebec
# /wiki/St._Catharines
# /wiki/Ontario_Heritage_Act
# /wiki/Heritage_Conservation_District
# /wiki/Naeen
# /wiki/Hassan_Pirnia
# /wiki/I.B.Tauris
# /wiki/Contemporary_art
# /wiki/Digital_Art
# /wiki/Polygon
# /wiki/Circle
# /wiki/Yang_Hui
# /wiki/Matteo_Ricci
# /wiki/Bodhisena
# /wiki/Gautama_Buddha
# /wiki/Rajgir
# /wiki/Enlightenment_in_Buddhism
# /wiki/Buddhist_funeral
# /wiki/Samanera
# /wiki/Mudra
# /wiki/ISBN_(identifier)
# /wiki/Hong_Kong_Public_Libraries
# /wiki/Kowloon
# /wiki/Anderson_Road,_Hong_Kong
# /wiki/Sau_Mau_Ping
# /wiki/List_of_places_in_Hong_Kong
# /wiki/List_of_urban_public_parks_and_gardens_in_Hong_Kong
# /wiki/Geography_of_Hong_Kong
# /wiki/ISBN_(identifier)
# /wiki/Uniform_Resource_Name
# /wiki/Tag_URI
# /wiki/Uniform_resource_name
# /wiki/Uniform_Resource_Identifier
# /wiki/Information_architecture
# /wiki/Categorization
# /wiki/Information_technology
# /wiki/Masatoshi_Shima
# /wiki/IBM_PC
# /wiki/IBM_ThinkPad_310
# /wiki/PS/note
# /wiki/PS/2
# /wiki/16550_UART
# /wiki/Camera_Link
# /wiki/Computer_Automated_Measurement_and_Control
# /wiki/SS-50_bus
# /wiki/HIL_bus
# /wiki/HP-UX
# /wiki/HP_TouchPad
# /wiki/AT%26T
# /wiki/DirecTV_blimp
# /wiki/TCM_Movies_(British_and_Irish_TV_channel)
# /wiki/Warner_Bros._World_Abu_Dhabi
# /wiki/Gremlins
# /wiki/John_Alvin
# /wiki/Scarface_(1983_film)
# /wiki/Deadline_Hollywood
# /wiki/Organizational_founder
# /wiki/School
# /wiki/Closed-circuit_television
# /wiki/Turkish_Data_Protection_Authority
# /wiki/Anonymity
# /wiki/Serbian_name
# /wiki/Milan_(given_name)
# /wiki/Slovakia
# /wiki/Nitra
# /wiki/%C4%BDudov%C3%ADtov%C3%A1
# /wiki/Kol%C3%AD%C5%88any
# /wiki/Hos%C5%A5ov%C3%A1
# /wiki/Podhorany,_Nitra_District
# /wiki/Nitra
# /wiki/Desmod
# /wiki/The_100_Greatest_Slovak_Albums_of_All_Time
# /wiki/Zvo%C5%88te,_zvonky
# /wiki/Pavol_Hammel
# /wiki/V%C3%A1clav_Patejdl
# /wiki/Mari%C3%A1n_Varga
# /wiki/B%C3%A9la_Bart%C3%B3k
# /wiki/ISBN_(identifier)
# /wiki/Advance_copy
# /wiki/Baen_Books
# /wiki/Larry_Correia
# /wiki/Science_fiction
# /wiki/Minority_Report_(film)
# /wiki/James_Berardinelli
# /wiki/Wired_(magazine)
# /wiki/Bon_App%C3%A9tit
# /wiki/YouTube_channel
# /wiki/Project_Nightingale
# /wiki/Electronic_health_records
# /wiki/Space_nursing
# /wiki/Gravity_assist
# /wiki/Plasma_(physics)
# /wiki/Glow_discharge
# /wiki/Striking_voltage
# /wiki/Avalanche_breakdown
# /wiki/ISBN_(identifier)
# /wiki/ISO_10206
# /wiki/Active_Oberon
# /wiki/PARC_(company)
# /wiki/Steve_Jobs
# /wiki/NeXT_MegaPixel_Display
# /wiki/Steve_Jobs
# /wiki/Louise_M._Davies_Symphony_Hall
# /wiki/Large_Four_Piece_Reclining_Figure_1972%E2%80%9373
# /wiki/Aurora_(Asawa)
# /wiki/California_Volunteers_(sculpture)
# /wiki/Finnila%27s_Finnish_Baths
# /wiki/Church_and_18th_Street_station
# /wiki/San_Francisco_Municipal_Railway
# /wiki/3_ft_6_in_gauge_railways
# /wiki/Norway
# /wiki/Market_share
# /wiki/Market_(economics)
# /wiki/Regional_economics
# /wiki/Monetary_economics
# /wiki/Afghan_afghani
# /wiki/Mohammed_Zahir_Shah
# /wiki/Pashto_language
# /wiki/Southern_Pashto
# /wiki/Pashtunistan
# /wiki/ISBN_(identifier)
# /wiki/Collection_(publishing)
# /wiki/Madrid
# /wiki/Buen_Retiro_Park
# /wiki/Giovanni_Battista_Crescenzi
# /wiki/Bartolomeo_Cavarozzi
# /wiki/Museo_del_Prado
# /wiki/Spanish_Royal_Collection
# /wiki/Tiepolo
# /wiki/Palazzo_Labia
# /wiki/Marionette
# /wiki/Matt_Stone
# /wiki/Robert_Lopez
# /wiki/Big_River_(musical)
# /wiki/Hamilton_(musical)
# /wiki/Cat_on_a_Hot_Tin_Roof
# /wiki/R.G._Armstrong
# /wiki/The_Great_White_Hope
# /wiki/The_Crucible
# /wiki/William_Stoughton_(judge)
# /wiki/Marcus_Morton_(judge)
# /wiki/Lemuel_Shaw
# /wiki/Foster_Hutchinson
# /wiki/Neil_L._Lynch
# /wiki/Harvard_Law_School
# /wiki/A_Civil_Action_(film)
# /wiki/A_Civil_Action
# /wiki/Woburn,_Massachusetts#Economy
# /wiki/Wilmington,_Massachusetts
# /wiki/Holliston,_Massachusetts
# /wiki/Non-attainment_area
# /wiki/National_Ambient_Air_Quality_Standards
# /wiki/Fresh_water
# /wiki/Fisheries_management
# /wiki/Seafood_Watch
# /wiki/Index_of_fishing_articles
# /wiki/Maori_cod
# /wiki/Wikidata
# /wiki/Memex
# /wiki/Office_of_the_future
# /wiki/Alfred_D._Crimi
# /wiki/The_Louis_Comfort_Tiffany_Foundation
# /wiki/Arthur_Deshaies
# /wiki/JSTOR_(identifier)
# /wiki/Digital_preservation
# /wiki/Centre_for_Development_of_Advanced_Computing
# /wiki/Digital_Locker_(India)
# /wiki/Kotak_Mahindra_Bank
# /wiki/Tata_Consumer_Products
# /wiki/S._Jaishankar
# /wiki/Harsh_Vardhan_(Delhi_politician)
# /wiki/Ministry_of_Health_and_Family_Welfare_(India)
# /wiki/Chandra_Shekhar
# /wiki/Border_Security_Force
# /wiki/Amit_Shah
# /wiki/List_of_members_of_the_17th_Lok_Sabha
# /wiki/Aonla_(Lok_Sabha_constituency)
# /wiki/Aonla_(Assembly_constituency)
# /wiki/Kursi_(Assembly_constituency)
# /wiki/Shekhupur_(Assembly_constituency)
# /wiki/Jewar_(Assembly_constituency)
# /wiki/Dibiyapur_(Assembly_constituency)
# /wiki/Baraut_(Assembly_constituency)
# /wiki/Ghazipur_Sadar_(Assembly_constituency)
# /wiki/Fatehpur_Sikri_(Assembly_constituency)
# /wiki/Election_Commission_of_India
# /wiki/Central_Directorate_for_Electoral_Services
# /wiki/Electoral_Commission_of_Seychelles
# /wiki/Central_Electoral_Commission_of_Armenia
# /wiki/2017_Armenian_parliamentary_election
# /wiki/2021_Armenian_parliamentary_election
# /wiki/Pro-Russian
# /wiki/Congolese_Party_of_Labour
# /wiki/Romanian_Communist_Party
# /wiki/History_of_the_Jews_in_Romania
# /wiki/Mizrahi_Jews
# /wiki/Targum
# /wiki/Catholic_Bible
# /wiki/Septuagint
# /wiki/Targum
# /wiki/Ashkenazi_Jews
# /wiki/Piyyutim
# /wiki/Yigdal
# /wiki/I_Have_a_Little_Dreidel
# /wiki/Maccabees
# /wiki/Books_of_the_Maccabees
# /wiki/5_Maccabees
# /wiki/Wayback_Machine
# /wiki/World_Wide_Web
# /wiki/Client_(computing)
# /wiki/Retroshare
# /wiki/Cryptographic_hash_function
# /wiki/Antoine_Joux
# /wiki/Laboratoire_d%27informatique_de_Paris_6
# /wiki/Scientific_computation
# /wiki/Computational_physics
# /wiki/Ab-initio
# /wiki/Ab_initio_methods_(nuclear_physics)
# /wiki/Stable_isotope
# /wiki/Radiocarbon_dating
# /wiki/Volcanic_eruptions
# /wiki/Water_vapor
# /wiki/Mars
# /wiki/Climate_of_Mars
# /wiki/Terrestrial_planet
# /wiki/Discoveries_of_exoplanets
# /wiki/List_of_potentially_habitable_exoplanets
# /wiki/Kepler-1632b
# /wiki/Rho_Coronae_Borealis_c
# /wiki/Delta_Coronae_Borealis
# /wiki/Abell_2142
# /wiki/Spiral_galaxy
# /wiki/Galactic_bulge
# /wiki/Low-surface-brightness_galaxy
# /wiki/Active_galactic_nucleus
# /wiki/Supermassive_black_hole
# /wiki/The_New_York_Times
# /wiki/Manuel_Mogato
# /wiki/Asia-Pacific_Economic_Cooperation
# /wiki/William_Stanley_Jevons
# /wiki/Business_cycle
# /wiki/Market_failure
# /wiki/George_Akerlof
# /wiki/Emanuel_Goldenweiser
# /wiki/Charles_Franklin_Dunbar
# /wiki/Matthew_B._Hammond
# /wiki/Allyn_Abbott_Young
# /wiki/Robert_J._Shiller
# /wiki/Black_Monday_(1987)
# /wiki/The_George_Washington_Law_Review
# /wiki/George_Washington_University_Art_Galleries
# /wiki/Corcoran_School_of_the_Arts_and_Design
# /wiki/George_Washington_University
# /wiki/1788%E2%80%9389_United_States_presidential_election
# /wiki/Model_Treaty
# /wiki/List_of_presidents_of_the_United_States
# /wiki/Harry_S._Truman
# /wiki/1952_United_States_presidential_election
# /wiki/United_States_Senate
# /wiki/Chuck_Schumer
# /wiki/Claude_Kitchin
# /wiki/National_Conference_of_Democratic_Mayors
# /wiki/Los_Angeles,_California
# /wiki/2020_Summer_Olympics
# /wiki/Canal%2B
# /wiki/Royal_Pains
# /wiki/Southwest_Championship_Wrestling
# /wiki/World_Wrestling_Entertainment
# /wiki/Ryan_Taylor_(wrestler)
# /wiki/Montel_Vontavious_Porter
# /wiki/Raul_Mendoza
# /wiki/Eva_Marie
# /wiki/Reality_television
# /wiki/Shear_Genius
# /wiki/Mannequin
# /wiki/WWE_Hardcore_Champion
# /wiki/Dustin_Rhodes
# /wiki/Ken_Patera
# /wiki/Wahoo_McDaniel
# /wiki/World_Class_Championship_Wrestling
# /wiki/WCWA_Texas_Brass_Knuckles_Championship
# /wiki/WCWA_Brass_Knuckles_Championship
# /wiki/House_show
# /wiki/Shoot_(professional_wrestling)
# /wiki/Kayfabe
# /wiki/Kane_(wrestler)
# /wiki/Billy_Kidman
# ...
# /wiki/Distributism
# /wiki/Mass_production
# /wiki/Manufacturing
# /wiki/Linens
# /wiki/Apron
# /wiki/Babygrow
# /wiki/American_English
# /wiki/Caddoan_languages
# /wiki/Pajalat
# /wiki/Bidai
# /wiki/Texas
# /wiki/Texians
# /wiki/History_of_Texas
# /wiki/Conquest_of_Chile
# /wiki/Chile
# /wiki/Garrison
# /wiki/Ottoman_Empire
# /wiki/ISBN_(identifier)
# /wiki/Motion_JPEG_2000
# /wiki/ISO/IEC_8820-5
# /wiki/ISO_4157
# /wiki/Prolog
# /wiki/TerminusDB
# /wiki/Collaborative_software
# /wiki/Douglas_Engelbart
# /wiki/Hypertext
# /wiki/HTML
# /wiki/Z_notation
# /wiki/Jim_Woodcock
# /wiki/Formal_Aspects_of_Computing
# /wiki/British_Computer_Society
# /wiki/The_Computer_Bulletin
# /wiki/London
# /wiki/Philharmonia_Orchestra
# /wiki/OCLC_(identifier)
# /wiki/Information_Today
# /wiki/Knowledge_management
# /wiki/Ignorance_management
# /wiki/Business_process
# /wiki/Corporate_crime
# /wiki/Madoff_investment_scandal
# /wiki/Indictment
# /wiki/Racial_discrimination_in_jury_selection
# /wiki/Abolitionism
# /wiki/Delia_Webster
# /wiki/ISBN_(identifier)
# /wiki/ISO_9897
# /wiki/ISO/IEC_4909
# /wiki/Motion_JPEG_2000
# /wiki/Bink_Video
# /wiki/JPEG
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_14750
# /wiki/ISO_45001
# /wiki/ISO_1
# /wiki/X.500
# /wiki/ASMO_449
# /wiki/%D8%B7
# /wiki/Gimel
# /wiki/Kaph
# /wiki/UTF-8
# /wiki/EUC-KR
# /wiki/State_(computer_science)
# /wiki/Finite_set
# /wiki/Willard_Van_Orman_Quine
# /wiki/Urelement
# /wiki/Unary_relation
# /wiki/Element_(mathematics)
# /wiki/Converse_relation
# /wiki/Set-builder_notation
# /wiki/Rational_number
# /wiki/Decimal
# /wiki/Orders_of_magnitude_(illuminance)
# /wiki/Computer_performance_by_orders_of_magnitude
# /wiki/Intel_4004
# /wiki/Core_Duo
# /wiki/Coffee_Lake_(microarchitecture)
# /wiki/Intel_Graphics_Technology#Kaby_Lake_Refresh_/_Amber_Lake_/_Coffee_Lake_/_Whiskey_Lake_/_Comet_Lake
# /wiki/Free_and_open-source_graphics_device_driver
# /wiki/Mac_OS_X
# /wiki/Mac_App_Store
# /wiki/Avie_Tevanian
# /wiki/United_States_Microsoft_antitrust_case
# /wiki/Opera_(web_browser)
# /wiki/Firefox_version_history#Release_history
# /wiki/History_of_the_Opera_web_browser#Version_7
# /wiki/Elm_(email_client)
# /wiki/Mozilla_Mail_%26_Newsgroups
# /wiki/Elm_(email_client)
# /wiki/Software_developer
# /wiki/List_of_programmers
# /wiki/Computer_security
# /wiki/Webpage
# /wiki/HTML
# /wiki/ISO/IEC_8859-7
# /wiki/Mac_OS_Croatian_encoding
# /wiki/BraSCII
# /wiki/National_Replacement_Character_Set
# /wiki/Code_page_924
# /wiki/Switzerland
# /wiki/Global_Competitiveness_Report
# /wiki/The_Gambia
# /wiki/Cameroon
# /wiki/Freedom_of_religion
# /wiki/Internationalism_(politics)
# /wiki/Blanquism
# /wiki/Labour_and_Socialist_International
# /wiki/Emanuel_Chobot
# /wiki/Polish_People%27s_Party_(Czechoslovakia)
# /wiki/Jan_Buzek
# /wiki/Byst%C5%99ice_(Fr%C3%BDdek-M%C3%ADstek_District)
# /wiki/Cieszyn_Vlachs
# /wiki/Silesians
# /wiki/Weimar_Republic
# /wiki/Free_State_of_Prussia
# /wiki/Saxony-Anhalt
# /wiki/Oschersleben_(Bode)
# /wiki/Brandenburg
# /wiki/Alliance_90/The_Greens
# /wiki/Political_centre
# /wiki/Hamas
# /wiki/United_States_Institute_of_Peace
# /wiki/National_Military_Strategy
# /wiki/Chairman_of_the_Joint_Chiefs_of_Staff
# /wiki/Chief_of_Defence_(Luxembourg)
# /wiki/Commander_of_the_Republic_of_Fiji_Military_Forces
# /wiki/Jioji_Konrote
# /wiki/Voice_of_Prophecy
# /wiki/Hope_Channel
# /wiki/Sportsman_Channel
# /wiki/Prime_Network
# /wiki/Fox_Sports_Pty_Limited
# /wiki/Wine_TV
# /wiki/Digital_cable
# /wiki/Metropolitan_Television_Alliance
# /wiki/CableCARD
# /wiki/Card_sharing
# /wiki/Internet
# /wiki/Instant_messaging
# /wiki/List_of_defunct_instant_messaging_platforms
# /wiki/IChat
# /wiki/Apple_Inc.
# /wiki/Financial_Times
# /wiki/Hargreaves_Parkinson
# /wiki/City_of_London
# /wiki/Paternoster_Square
# /wiki/Gold_leaf
# /wiki/Ferdinand_and_Isabella
# /wiki/Casta
# /wiki/Racial_polarization
# /wiki/Laissez-faire_racism
# /wiki/Covert_racism
# /wiki/Ethnic_pornography
# /wiki/Ethnic_democracy
# /wiki/Ethnopsychopharmacology
# /wiki/Doi_(identifier)
# /wiki/ISLISP
# /wiki/MPEG-4_Part_3
# /wiki/TwinVQ
# /wiki/MT9
# /wiki/Siren_(codec)
# /wiki/RTAudio
# /wiki/TTA_(codec)
# /wiki/On2_Technologies
# /wiki/Paul_Otellini
# /wiki/Google_Keep
# /wiki/Google_Translate
# /wiki/Tok_Pisin
# /wiki/Determiner_(linguistics)
# /wiki/Interrogative_word
# /wiki/Esperanto
# /wiki/Latin_script
# /wiki/Belgium
# /wiki/European_Commission
# /wiki/Germany
# /wiki/List_of_countries_by_population
# /wiki/Eritrea
# /wiki/Spain
# /wiki/Region_of_Murcia
# /wiki/Second_Spanish_Republic
# /wiki/Health_care_in_Spain
# /wiki/Economic_history_of_Spain
# /wiki/List_of_Spanish_autonomous_communities_by_unemployment_rate
# /wiki/Catalonia
# /wiki/World_Heritage_Site
# /wiki/Lists_of_World_Heritage_Sites_in_the_Americas
# /wiki/World_Heritage_Site
# /wiki/Great_Barrier_Reef
# /wiki/CURV
# /wiki/Guybon_Chesney_Castell_Damant
# /wiki/German_submarine_U-352
# /wiki/Diving_environment
# /wiki/Myriam_Seco
# /wiki/Michael_Barratt_(astronaut)
# /wiki/Underwater_cycling
# /wiki/Index_of_underwater_diving
# /wiki/James_Talacek
# /wiki/Powerhead_(firearm)
# /wiki/Diving_mask
# /wiki/National_Association_for_Cave_Diving
# /wiki/The_Diver
# /wiki/Integrated_weights
# /wiki/Martin%27s_Haven
# /wiki/Low_impact_diving
# /wiki/Pluragrotta
# /wiki/Koichi_Wakata
# /wiki/Loch_Long
# /wiki/MS_Mikhail_Lermontov
# /wiki/Decompression_theory
# /wiki/Gas_storage_tube
# /wiki/National_Diving_and_Activity_Centre
# /wiki/Deep_diving
# /wiki/Decompression_trapeze
# /wiki/Jonathan_Bird
# /wiki/LR5
# /wiki/Scorpio_ROV
# /wiki/La_Belle_(ship)
# /wiki/SS_Rosehill
# /wiki/Decompression_trapeze
# /wiki/Poor_Knights_Islands
# /wiki/National_Diving_and_Activity_Centre
# /wiki/Dive_reel
# /wiki/Underwater_acoustic_positioning_system
# /wiki/Diving_supervisor
# /wiki/Sonar
# /wiki/Cave_Diving_Group
# /wiki/Diving_Science_and_Technology
# /wiki/Diver_detection_sonar
# /wiki/Maltese_patrol_boat_P29
# /wiki/Diving_compass
# /wiki/United_States_Navy_SEALs
# /wiki/Ama_(diving)
# /wiki/SS_Thistlegorm
# /wiki/Scorpaeniformes
# /wiki/Bathylutichthyidae
# /wiki/Taxonomy_(biology)
# /wiki/Cluster_analysis
# /wiki/Sample_median
# /wiki/Statistics
# /wiki/Statistical_model
# /wiki/Parametric_model
# /wiki/Weibull_distribution
# /wiki/Logistic_distribution
# /wiki/Negative_binomial_distribution
# /wiki/Maximum_entropy_probability_distribution
# /wiki/Laplace_distribution
# /wiki/Support_(mathematics)
# /wiki/Hausdorff_space
# /wiki/Topological_space
# /wiki/Hemicontinuity
# /wiki/ISBN_(identifier)
# /wiki/File_Allocation_Table
# /wiki/110_film
# /wiki/ISO_4157
# /wiki/Legal_Entity_Identifier
# /wiki/ISO_8373
# /wiki/ISO_10007
# /wiki/OCR-B
# /wiki/ISO_10303-28
# /wiki/ISO_31-0
# /wiki/HTML
# /wiki/Markdown
# /wiki/Setext
# /wiki/Parsing
# /wiki/ISBN_(identifier)
# /wiki/ISO_11784_and_ISO_11785
# /wiki/Digital_object_identifier
# /wiki/OpenURL
# /wiki/ISSN_(identifier)
# /wiki/ISO_26262
# /wiki/Automotive_Safety_Integrity_Level
# /wiki/DO-178C
# /wiki/ARP4761
# /wiki/Association_of_Licensed_Automobile_Manufacturers
# /wiki/Detroit
# /wiki/Quick_Lane_Bowl
# /wiki/List_of_announcers_of_major_college_bowl_games
# /wiki/Penn_Quakers_football
# /wiki/Rose_Bowl_Game
# /wiki/TaxSlayer_Bowl
# /wiki/Nebraska_Cornhuskers_football
# /wiki/1920_Big_Ten_Conference_football_season
# /wiki/Chuck_Carney
# /wiki/Clyde_Lovellette
# /wiki/Richard_Washington
# /wiki/Howard_Porter_(basketball)
# /wiki/Probation_officer
# /wiki/Bureaucratic
# /wiki/Promulgation
# /wiki/Grand_Duke_of_Luxembourg
# /wiki/Monarchy_of_Belgium
# /wiki/Princess_Delphine_of_Belgium
# /wiki/Princess_Louise_of_Belgium
# /wiki/Princess_Sibylla_of_Saxe-Coburg_and_Gotha
# /wiki/Princess_Patricia_of_Connaught
# /wiki/Princess_Mary_Adelaide_of_Cambridge
# /wiki/London
# /wiki/London_Inner_Ring_Road
# /wiki/M1_motorway
# /wiki/A696_road
# /wiki/Edinburgh
# /wiki/Transport_in_Edinburgh
# /wiki/Devolution#Scotland
# /wiki/Colonial_empire
# /wiki/Kingdom_of_Scotland
# /wiki/Calvinism
# /wiki/United_States_Bill_of_Rights
# /wiki/Archivist_of_the_United_States
# /wiki/United_States_Code
# /wiki/Judicial_Code_of_1911
# /wiki/U.S._circuit_courts
# /wiki/Alexander_S._Johnson
# /wiki/Alexander_Bryan_Johnson
# /wiki/William_Stephens_Smith
# /wiki/Grenada
# /wiki/ISSN_(identifier)
# /wiki/126_film
# /wiki/Process_Specification_Language
# /wiki/ISO_20022
# /wiki/Prolog
# /wiki/Prolog_syntax_and_semantics#Definite_clause_grammars
# /wiki/Arity
# /wiki/Two%27s_complement
# /wiki/Bitwise_operation
# /wiki/Projection_function
# /wiki/Set_theory
# /wiki/Power_set
# /wiki/Axiom_of_power_set
# /wiki/Mathematics
# /wiki/Group_(mathematics)
# /wiki/Dicyclic_group
# /wiki/Glossary_of_group_theory
# /wiki/Solenoid_(mathematics)
# /wiki/%C4%8Cech_cohomology
# /wiki/Constant_sheaf
# /wiki/Open_set
# /wiki/Kazimierz_Kuratowski
# /wiki/Warsaw_Scientific_Society
# /wiki/Poland
# /wiki/Prime_Minister_of_Poland
# /wiki/President_of_Russia
# /wiki/List_of_lakes_of_Russia
# /wiki/Russian_Civil_War
# /wiki/Kronstadt_rebellion
# /wiki/Russian_Empire
# /wiki/Racism_in_Russia
# /wiki/Counter-jihad
# /wiki/Prejudice
# /wiki/Doi_(identifier)
# /wiki/International_Standard_Musical_Work_Code
# /wiki/MPEG-21
# /wiki/ISO_19092-1
# /wiki/ISO_6385
# /wiki/ISO_31
# /wiki/ISO/IEC_80000
# /wiki/ISO/IEC_8820-5
# /wiki/ISO/IEC_15504
# /wiki/Reference_model
# /wiki/Von_Neumann_architecture
# /wiki/Minimal_instruction_set_computer
# /wiki/Field-programmable_object_array
# /wiki/Reconfigurable_computing
# /wiki/High-level_synthesis
# /wiki/Graphics_processing_unit
# /wiki/Transistor_count
# /wiki/Resistive_random-access_memory
# /wiki/Mobile_translation
# /wiki/Proactionary_principle
# /wiki/Technological_paradigm
# /wiki/Joseph_Schumpeter
# /wiki/Edward_Chamberlin
# /wiki/La_Conner,_Washington
# /wiki/Calista_(steamboat)
# /wiki/Old_Settler_(sternwheeler)
# /wiki/Crawford_and_Reid_(shipbuilders)
# /wiki/Elk_(steam_tug)
# /wiki/Puget_Sound_Mosquito_Fleet
# /wiki/Puget_Sound
# /wiki/Oregon_Country
# /wiki/Bechuanaland_Protectorate
# /wiki/Latitude
# /wiki/Meridian_(geography)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISO_7002
# /wiki/X3D
# /wiki/ISO/IEC_29110
# /wiki/Library_of_Congress
# /wiki/Tidal_Basin
# /wiki/Potomac_River
# /wiki/Virginia
# /wiki/2019_Virginia_political_crisis
# /wiki/Virginia
# /wiki/France
# /wiki/Mexico
# /wiki/BBVA_Bancomer
# /wiki/BBVA_Provincial
# /wiki/Banco_Bilbao_Vizcaya_Argentaria
# /wiki/South_America
# /wiki/Supercontinent
# /wiki/Precambrian
# /wiki/Geologic_period
# /wiki/Era_(geology)
# /wiki/Absolute_dating
# /wiki/Glycine
# /wiki/Glucogenic_amino_acids
# /wiki/Biochemistry
# /wiki/ISBN_(identifier)
# /wiki/Advance_copy
# /wiki/Reading
# /wiki/Florida_State_University
# /wiki/University_of_Texas_at_Arlington
# /wiki/Texas_A%26M_University%E2%80%93Central_Texas
# /wiki/Arizona_Western_College
# /wiki/Mesa_Community_College
# /wiki/Southwest_University_of_Visual_Arts
# /wiki/Mohave_Community_College
# /wiki/Northland_Pioneer_College
# /wiki/Prescott_College
# /wiki/Glendale_Community_College_(Arizona)
# /wiki/Embry%E2%80%93Riddle_Aeronautical_University,_Prescott
# /wiki/Mohave_Community_College
# /wiki/Tohono_O%CA%BCodham_Community_College
# /wiki/Stone_Child_College
# /wiki/Twin_Hills_Colony,_Montana
# /wiki/Area_code_406
# /wiki/Condon,_Montana
# /wiki/Coloma,_Montana
# /wiki/Vein_(geology)
# /wiki/Cataclasite
# /wiki/Fault_breccia
# /wiki/Rock_(geology)
# /wiki/Construction_aggregate
# /wiki/Fiber-reinforced_concrete
# /wiki/Steel
# /wiki/Pipeline_transport
# /wiki/Benzene
# /wiki/Catalyst
# /wiki/Enzyme
# /wiki/Doi_(identifier)
# /wiki/Guidelines_for_the_Definition_of_Managed_Objects
# /wiki/IEC_61508
# /wiki/OpenDocument
# /wiki/Fiber_Distributed_Data_Interface
# /wiki/ISO_6344
# /wiki/ISO_11992
# /wiki/ISO/IEC_2022
# /wiki/Digital_Addressable_Lighting_Interface
# /wiki/XPL_Protocol
# /wiki/OBIX
# /wiki/Highway_Addressable_Remote_Transducer_Protocol
# /wiki/Vehicle_Area_Network
# /wiki/SLIMbus
# /wiki/Arm_Holdings
# /wiki/GeForce
# /wiki/United_States_Dollar
# /wiki/Canadian_dollar
# /wiki/Barbadian_dollar
# /wiki/Thaler
# /wiki/Leo_Belgicus
# /wiki/Allegory_of_Hispania
# /wiki/Handala
# /wiki/Dutch_Maiden
# /wiki/Rotterdam
# /wiki/7_For_All_Mankind
# /wiki/VF_Corporation
# /wiki/The_North_Face
# /wiki/List_of_alpine_clubs
# /wiki/Nuttall_Encyclopaedia
# /wiki/United_Kingdom
# /wiki/Saint_Helena,_Ascension_and_Tristan_da_Cunha
# /wiki/British_Virgin_Islands
# /wiki/History_of_Australia_(1901%E2%80%9345)
# /wiki/Wayback_Machine
# /wiki/VirusTotal
# /wiki/Google_Safe_Browsing
# /wiki/Android_Go
# /wiki/Comparison_of_Java_and_Android_API
# /wiki/Google
# /wiki/California
# /wiki/Criollo_people
# /wiki/Enlightenment_in_Spain
# /wiki/Iguape_War
# /wiki/History_of_Brazil
# /wiki/A_scene_from_the_opening_ceremony_of_the_2016_Summer_Olympics_in_Rio_de_Janeiro.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-ee18b17d20d4> in <module>
#      15     newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      16     print(newArticle)
# ---> 17     links = getLinks(newArticle)
#
# <ipython-input-2-ee18b17d20d4> in getLinks(articleUrl)
#       7 random.seed(datetime.datetime.now())
#       8 def getLinks(articleUrl):
# ----> 9     html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
#      10     bs = BeautifulSoup(html, 'html.parser')
#      11     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
'''
집합 자료형 set
1. 중복x   unique한값만 의미있음
2. 순서x

//가장많이쓰는 방법 : 하나의 row 또는 하나의 column을 리스트로 가져옴 → 집합자료형으로 캐스팅해서 하나씩 걸러냄 → 다시 리스트로 캐스팅
A=[1,4,2,3,1,2]
SA = set(A) 	//{1,4,2,3}
NEWA = list(SA) 	//[1,4,2,3]
'''
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')): # href 속성값이 '/wiki/'로 시작하는 모든 a태그 하나씩
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages: # 한 번 갔던 페이지는 중복적으로 들어가지 않도록
                # We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
                getLinks(newPage) # 재귀함수 => Stack 메모리 문제로, 보통 함수가 끝나지 않고 1000번 정도 재귀함수 돌다 보면 명령어(함수)가 계속 쌓이기만 해서 죽어버림.
                                                # 컴파일한다는 것이 사실은 코드를 전부 어셈블리 명령어로 바꿔 순차적으로 수행하는 것이기 때문. 
                                  # 어떤 회사들은 실수 방지하려고 => 1. 재귀함수(stack영역) 쓰지 말아라! 2. 메모리에 동적할당(heap영역, 해제 필요) 하지 말아라!
getLinks('')
'''
계속 
/wiki/Wikipedia
/wiki/Wikipedia:Protection_policy#semi
/wiki/Wikipedia:Requests_for_page_protection
/wiki/Wikipedia:Requests_for_permissions
/wiki/Wikipedia:Protection_policy#extended
/wiki/Wikipedia:Lists_of_protected_pages
  ㆍㆍㆍ 받아오다가
most recent call last 뜸. 
'''
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Protection_policy#extended
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:WikiProject_Reliability
# /wiki/Wikipedia:WRE
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Protection_policy#move
# /wiki/Wikipedia:WikiProject_Parliamentary_Procedure
# /wiki/File:People_icon_dead.svg
# /wiki/User:StevenDH
# /wiki/Wikipedia:User_pages
# /wiki/Wikipedia:FUW
# /wiki/Wikipedia:Protection_policy#template
# /wiki/Wikipedia:Party_and_person
# /wiki/File:Essay.svg
# /wiki/File:Essay.png
# /wiki/File:To_Commons.svg
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# /wiki/User_talk:Robert_Merkel
# /wiki/User_talk:Robert_Merkel/ancient
# /wiki/User:RjLesch
# /wiki/Des_Moines,_Iowa
# /wiki/Des_Moines_(disambiguation)
# /wiki/Des_Moines_metropolitan_area
# /wiki/Metropolitan_statistical_area
# /wiki/List_of_metropolitan_statistical_areas
# /wiki/List_of_primary_statistical_areas_of_the_United_States
# /wiki/File:Pano_Manhattan2007_amk.jpg
# /wiki/User:AngMoKio
# /wiki/Wikipedia:Babel
# /wiki/List_of_ISO_639-1_codes
# /wiki/File:Question_book-new.svg
# /wiki/Scalable_Vector_Graphics
# /wiki/SVG_(disambiguation)
# /wiki/SVG
# /wiki/Wikipedia:SVG_help
# /wiki/Wikipedia:Graphic_Lab/Resources/SVG
# /wiki/Wikipedia:Graphics_Lab
# /wiki/Wikipedia:Graphics_Lab/Illustration_workshop
# /wiki/Wikipedia:Graphics_Lab/Photography_workshop
# /wiki/Wikipedia:Graphics_Lab/Map_workshop
# /wiki/Wikipedia:Shortcut
# /wiki/Wikipedia:Keyboard_shortcuts
# /wiki/Wikipedia:WikiProject_Kansas
# /wiki/Wikipedia:WikiProject
# /wiki/WikiProject
# /wiki/Wiki
# /wiki/File:En-Wiki2.ogg
# /wiki/User:Dmcdevit
# /wiki/Wikipedia:GLAM-Wiki
# /wiki/Wikipedia:GLAM/About
# /wiki/Wikipedia:GLAM
# /wiki/Wikipedia:GLAM/Contribute
# /wiki/Wikipedia:GLAM/Connect
# /wiki/Wikipedia:GLAM/Bookshelf
# /wiki/Wikipedia:GLAM/Projects
# /wiki/Wikipedia:GLAM/Beginner%27s_guide_to_Wikipedia
# /wiki/Wikipedia:GLAM/Newsletter
# /wiki/Special:MyTalk
# /wiki/Special:NewSection/User_talk:106.241.43.86
# /wiki/File:User-info.svg
# /wiki/File:Full-protection-shackle.svg
# /wiki/Wikipedia:Criteria_for_speedy_deletion#F8
# /wiki/Wikipedia:Revision_deletion
# /wiki/Wikipedia:Deletion_review
# /wiki/Wikipedia:Deletion_discussions
# /wiki/Wikipedia:Deletion_policy
# /wiki/Wikipedia:Deletion_process
# /wiki/Wikipedia:Guide_to_deletion
# /wiki/Wikipedia:General_disclaimer
# /wiki/Wikipedia:Protection_policy#full
# /wiki/Wikipedia:Child_protection
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Notability_(people)
# /wiki/Wikipedia:BIO
# /wiki/Wikipedia:Autobiography
# /wiki/Wikipedia:AUTOBLOCK
# /wiki/Template:Autoblock
# /wiki/Wikipedia:Autoblock
# /wiki/Wikipedia:UTRS
# /wiki/Wikipedia:OTRS
# /wiki/Wikipedia:OTRS_noticeboard
# /wiki/Template:Noticeboard_links
# /wiki/Template_talk:Noticeboard_links
# /wiki/Wikipedia:Talk_page_guidelines
# /wiki/Help:Talk_pages
# /wiki/Help:Template
# /wiki/Wikipedia:Template_index
# /wiki/MOS:TM
# /wiki/Wikipedia:Manual_of_Style
# /wiki/Wikipedia:Policies_and_guidelines#guide
# /wiki/Wikipedia:WikiProject_Politics
# /wiki/File:A_coloured_voting_box.svg
# /wiki/Category:Wikipedia_files_on_Wikimedia_Commons
# /wiki/Help:Category
# /wiki/Wikipedia:Categorization
# /wiki/Wikipedia:WikiProject_Cats
# /wiki/Wikipedia:CATP
# /wiki/Wikipedia:WikiProject_Council/Guide
# /wiki/Wikipedia:WikiProject_Council
# /wiki/File:WikiProject_Council_with_transparent_background.svg
# /wiki/Special:WhatLinksHere/File:WikiProject_Council_with_transparent_background.svg
# /wiki/Talk:Atlas_Shrugged
# /wiki/Wikipedia:Vital_articles/Level/5/Arts
# /wiki/Wikipedia:Vital_articles
# /wiki/Wikipedia:VA
# /wiki/Wikipedia:WikiProject_Vital_Articles
# /wiki/Wikipedia:WikiProject_Council/Directory
# /wiki/Wikipedia:Community_portal
# /wiki/Wikipedia:Dashboard
# /wiki/Wikipedia:Department_directory
# /wiki/Wikipedia:Maintenance
# /wiki/Wikipedia:Task_Center
# /wiki/Wikipedia:Be_bold
# /wiki/MOS:BOLD
# /wiki/Help:Wiki_markup
# /wiki/Wikitext
# /wiki/Wiki_(disambiguation)
# /wiki/Wikipedia:Glossary
# /wiki/Wikipedia:Wikipedia_abbreviations
# /wiki/Wikipedia:Manual_of_Style/Abbreviations
# /wiki/Wikipedia:List_of_shortcuts
# /wiki/Wikipedia:About
# /wiki/Help:About_help_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:List_of_policies#Procedural
# /wiki/Template:Nutshell
# /wiki/Template:Nutshell/doc
# /wiki/Wikipedia:Template_documentation
# /wiki/File:Twemoji_1f527.svg
# /wiki/Special:WhatLinksHere/File:Twemoji_1f527.svg
# /wiki/Help:Editing
# /wiki/Wikipedia:Editing_policy
# /wiki/Wikipedia:List_of_guidelines#Editing
# /wiki/Wikipedia:GUIDELINE
# /wiki/Help:Introduction
# /wiki/Special:RecentChanges
# /wiki/MediaWiki:Recentchangestext
# /wiki/MediaWiki_talk:Recentchangestext
# /wiki/File:Namespace_MediaWiki.svg
# /wiki/Special:AllMessages
# /wiki/Help:MediaWiki_namespace
# /wiki/MediaWiki
# /wiki/Wikimedia
# /wiki/Wikipedia_community
# /wiki/Wikipedia:Wikipedians
# /wiki/Special:ListUsers
# /wiki/Wikipedia:Why_create_an_account%3F
# /wiki/File:Wikimedia_Community_Logo.svg
# /wiki/Special:WhatLinksHere/File:Wikimedia_Community_Logo.svg
# /wiki/Genealogy
# /wiki/Genealogy_(philosophy)
# /wiki/Wikipedia:Make_technical_articles_understandable
# /wiki/Wikipedia:Village_pump_(technical)
# /wiki/Wikipedia:Village_pump_(policy)
# /wiki/Wikipedia:Village_pump_(proposals)
# /wiki/Wikipedia:Village_pump_(idea_lab)
# /wiki/Wikipedia:Village_pump_(WMF)
# /wiki/Wikipedia:Village_pump_(miscellaneous)
# /wiki/Special:NewSection/Wikipedia:Village_pump_(miscellaneous)
# /wiki/IP_address
# /wiki/Wikipedia:User_access_levels#Unregistered_(IP_or_not_logged_in)_users
# /wiki/Wikipedia:Requests_for_adminship
# /wiki/Wikipedia:Requested_articles
# /wiki/Wikipedia:Recent_additions
# /wiki/Wikipedia:DYKNA
# /wiki/Template_talk:Did_you_know
# /wiki/Wikipedia:Did_you_know
# /wiki/Template_talk:Did_you_know#Instructions_for_nominators
# /wiki/Wikipedia_talk:Did_you_know
# /wiki/Wikipedia:Main_Page/Errors
# /wiki/Wikipedia:Main_Page
# /wiki/Free_content
# /wiki/Wikipedia:Free_content
# /wiki/Wikipedia:Wikipedia_is_free_content
# /wiki/Wikipedia:Consensus
# /wiki/Wikipedia:Conflict_of_interest
# /wiki/Wikipedia:Conflict_of_interest/Noticeboard
# /wiki/Wikipedia:WikiProject_Numismatics
# /wiki/Greek_language
# /wiki/Proto-Greek_language
# /wiki/Pre-Greek_substrate
# /wiki/History_of_Greece
# /wiki/Nation_state
# /wiki/Nation
# /wiki/Nation_(disambiguation)
# /wiki/Nation_Records
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources/Noticeboard
# /wiki/Wikipedia:Noticeboards
# /wiki/Wikipedia:Consensus#Achieving_consensus
# /wiki/Help:Edit_conflict
# /wiki/Wikipedia:Edit_warring
# /wiki/Wikipedia:NOTBATTLE
# /wiki/Wikipedia:NOT_(disambiguation)
# /wiki/Wikipedia:What_Wikipedia_is_not
# /wiki/Wikipedia:What_%22Ignore_all_rules%22_means#Use_common_sense
# /wiki/Wikipedia:Ignore_all_rules
# /wiki/File:Wikipedia_Ignore_All_Rules.ogg
# /wiki/User:BlackAmerican
# /wiki/File:Flag_of_Japan.svg
# /wiki/Wikipedia:FFD
# /wiki/File:Gtk-go-down.svg
# /wiki/GNOME
# /wiki/Gnome_(disambiguation)
# /wiki/Wikipedia:WikiGnome
# /wiki/Humour
# /wiki/Wikipedia:Humor
# /wiki/Wikipedia:SILLY
# /wiki/Wikipedia:HUMOR
# /wiki/Wikipedia:WikiProject_Comedy
# /wiki/Wikipedia:Department_of_Fun
# /wiki/Wikipedia:Fun
# /wiki/Wikipedia:FUN
# /wiki/File:Face-grin.svg
# /wiki/User:Thomas_Linard
# /wiki/Category:User_fr-N
# /wiki/French_language
# /wiki/Help:IPA/French
# /wiki/Help:IPA
# /wiki/Help:Special_characters#IPA_symbols
# /wiki/Wikipedia:Notability_(fiction)
# /wiki/Wikipedia:Manual_of_Style/Writing_about_fiction
# /wiki/Wikipedia_talk:Manual_of_Style/Writing_about_fiction
# /wiki/Wikipedia_talk:Manual_of_Style
# /wiki/Special:NewSection/Wikipedia_talk:Manual_of_Style
# /wiki/Help:Using_talk_pages
# /wiki/Wikipedia:Project_namespace#Wikipedia_how-to_and_information_pages
# /wiki/Category:Wikipedia_project_content_guidelines
# /wiki/Wikipedia:Categorization#Non-article_and_maintenance_categories
# /wiki/Wikipedia:HotCat
# /wiki/Wikipedia:Hat_collecting
# /wiki/Wikipedia:PERM
# /wiki/Wikipedia:Requesting_copyright_permission
# /wiki/Wikipedia:User_access_levels
# /wiki/Wikipedia:Rights_(disambiguation)
# /wiki/Wikipedia:WikiProject_Conservatism
# /wiki/Wikipedia:Right_(disambiguation)
# /wiki/Wikipedia:Courtesy_vanishing
# /wiki/Wikipedia:Manual_of_Style/Text_formatting#Mixed_right-to-left_text
# /wiki/Wikipedia_talk:Manual_of_Style/Text_formatting
# /wiki/Wikipedia:Manual_of_Style/Text_formatting
# /wiki/Help:Wiki_markup#Format
# /wiki/Wikipedia:Edit_summary_legend
# /wiki/Help:HTML_in_wikitext
# /wiki/Wikipedia:HTML_5
# /wiki/HTML_5
# /wiki/File:HTML5_logo_and_wordmark.svg
# /wiki/File:HTML5_Logo.svg
# /wiki/Special:MyContributions
# /wiki/Help:User_contributions
# /wiki/Wikipedia:Namespace
# /wiki/Wikipedia:WikiProject_Nova_Scotia
# /wiki/Nova_Scotia
# /wiki/Nova_Scotia_(disambiguation)
# /wiki/Nova_Scotia_(ship)
# /wiki/HMS_Nova_Scotia
# /wiki/HMS_Ferret
# /wiki/Shore_establishment
# /wiki/Stone_ship
# /wiki/Ship_burial
# /wiki/Burial_at_sea
# /wiki/BioShock_Infinite:_Burial_at_Sea
# /wiki/Wikipedia:Good_articles
# /wiki/Wikipedia:Good_article_criteria
# /wiki/Wikipedia:Good_article_nominations/Instructions
# /wiki/Wikipedia:Good_article_nominations
# /wiki/Wikipedia:WikiProject_Good_articles/GAN_Backlog_Drives/July_2021
# /wiki/Wikipedia:WikiProject_Good_articles
# /wiki/Wikipedia:Teahouse
# /wiki/Wikipedia:Teahouse#top
# /wiki/Wikipedia:Teahouse#skip-to-bottom-anchor
# /wiki/User:Maproom
# /wiki/Template:Mapframe
# /wiki/Special:Map/9/35.9/-106.56/en
# /wiki/Main_Page
# /wiki/Encyclopedia
# /wiki/Encyclopedia_(disambiguation)
# /wiki/Encyclopedia_(album)
# /wiki/File:The_Drums_-_Encyclopedia.jpg
# /wiki/Wikipedia:Non-free_content
# /wiki/Wikipedia:WPFU
# /wiki/Wikipedia:WikiProject_Images_and_Media
# /wiki/Template:WikiProject_status
# /wiki/Template:WikiProject_status/doc
# /wiki/Wikipedia:Subpages
# /wiki/Wikipedia:SP_(disambiguation)
# /wiki/Wikipedia:Sister_projects
# /wiki/Category:Wikipedia_style_guidelines
# /wiki/Wikipedia:What_is_an_article%3F
# /wiki/Wikipedia:Naming_conventions_(definite_or_indefinite_article_at_beginning_of_name)
# /wiki/Category:Wikipedia_naming_conventions
# /wiki/Category:Naming_conventions
# /wiki/Help:Categories
# /wiki/Wikipedia:FAQ/Readers
# /wiki/Wikipedia:FAQ
# /wiki/Help:Contents
# /wiki/Help:Menu
# /wiki/Wikipedia:Administration
# /wiki/Wikipedia:Administrators
# /wiki/Wikipedia_administrators
# /wiki/File:Wikipedia_Administrator.svg
# /wiki/Special:WhatLinksHere/File:Wikipedia_Administrator.svg
# /wiki/User_talk:Deb
# /wiki/User:Deb
# /wiki/Wikipedia:Ten_Year_Society
# /wiki/File:Ten_Year_Society.svg
# /wiki/User:Scott
# /wiki/File:Ok-blue.png
# /wiki/Talk:Absa_Group_Limited/Archives/2019
# /wiki/Talk:Absa_Group_Limited
# /wiki/Absa_Group_Limited
# /wiki/ABSA_(disambiguation)
# /wiki/ABSA_Cargo_Airline
# /wiki/File:LATAM_Cargo_logo.svg
# /wiki/File:Latam-logo_-v_(Indigo).svg
# /wiki/LATAM_Airlines_Group
# /wiki/LATAM_(disambiguation)
# /wiki/Latin_America
# /wiki/Latin_American
# /wiki/Latino_Americans
# /wiki/Hispanic_and_Latino_(ethnic_categories)
# /wiki/Wikipedia:No_original_research
# /wiki/Wikipedia:WikiProject_Norway
# /wiki/Wikipedia:Notability
# /wiki/Wikipedia:NPOV
# /wiki/Wikipedia:Describing_points_of_view
# /wiki/Wikipedia:NOTOPINION
# /wiki/Wikipedia:Core_content_policies
# /wiki/Wikipedia:Neutral_point_of_view
# /wiki/Wikipedia:Neutral_point_of_view/Noticeboard
# /wiki/Category:Wikipedia_backlog
# /wiki/Category:Wikipedia_maintenance
# /wiki/Category:Tracking_categories
# /wiki/Category:Container_categories
# /wiki/Wikipedia:SUBCAT
# /wiki/Wikipedia:WikiProject_Categories
# /wiki/Wikipedia_talk:Categorization
# /wiki/Wikipedia_talk:Categories_for_discussion
# /wiki/Wikipedia_talk:CFD/W
# /wiki/Wikipedia:Categories_for_discussion
# /wiki/Wikipedia:Articles_for_creation/Categories
# /wiki/Wikipedia:Articles_for_creation
# /wiki/Wikipedia:WikiProject_Articles_for_creation
# /wiki/Wikipedia_talk:WikiProject_Articles_for_creation
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Submissions
# /wiki/Category:Pending_AfC_submissions
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Submissions/List
# /wiki/Wikipedia:AfC_sorting
# /wiki/File:AFC-Logo.svg
# /wiki/File:Crystal_Clear_action_edit_add.png
# /wiki/Special:WhatLinksHere/File:Crystal_Clear_action_edit_add.png
# /wiki/Talk:Addiction
# /wiki/Addiction
# /wiki/Addiction_(disambiguation)
# /wiki/Addiction_(journal)
# /wiki/Outline_of_academic_disciplines
# /wiki/File:Academic_disciplines_(collage).jpg
# /wiki/User:CaliphOfAldebaran
# /wiki/Discipline_(academia)
# /wiki/School_discipline
# /wiki/Academic_discipline
# /wiki/Category:Research
# /wiki/Research
# /wiki/Research_(disambiguation)
# /wiki/Research,_Victoria
# /wiki/Melbourne
# /wiki/Melbourne_City_Centre
# /wiki/City_of_Melbourne
# /wiki/Melbourne_(disambiguation)#Other_places
# /wiki/Melbourne_city_centre
# /wiki/Victoria_(Australia)
# /wiki/Victoria_(disambiguation)#Places
# /wiki/Victoria,_British_Columbia
# /wiki/Greater_Victoria
# /wiki/Greater_Vit%C3%B3ria
# /wiki/A_Grande_Vit%C3%B3ria
# /wiki/File:A_Grande_Vit%C3%B3ria_Poster.jpg
# /wiki/Wikipedia:Non-free_content_criteria#4
# /wiki/Wikipedia:EDP_Sciences
# /wiki/Wikipedia:TWL
# /wiki/Wikipedia:WikiProject_Libraries
# /wiki/Wikipedia_talk:WikiProject_Libraries
# /wiki/Wikipedia:WikiProject_Libraries/Introduction
# /wiki/Wikipedia_talk:WikiProject_Libraries/Introduction
# /wiki/Wikipedia:WikiProject_Libraries/Members
# /wiki/Wikipedia_talk:WikiProject_Libraries/Members
# /wiki/Wikipedia:WikiProject_Libraries/Resources
# /wiki/Wikipedia_talk:WikiProject_Libraries/Resources
# /wiki/Wikipedia:WikiProject_Libraries/Assessment
# /wiki/Wikipedia_talk:WikiProject_Libraries/Assessment
# /wiki/Special:NewSection/Wikipedia_talk:WikiProject_Libraries/Assessment
# /wiki/Wikipedia:Signatures
# /wiki/Wikipedia:Wikipedia_Signpost
# /wiki/Wikipedia:Wikipedia_Signpost/2021-04-25/From_the_editor
# /wiki/Wikipedia:Wikipedia_Signpost/2021-04-25
# /wiki/Wikipedia:Wikipedia_Signpost/2021-04-25/Disinformation_report
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/2021-04-25
# /wiki/Wikipedia:Wikipedia_Signpost/Archives
# /wiki/Wikipedia_talk:Wikipedia_Signpost
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Suggestions
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom
# /wiki/Wikipedia:Wikipedia_Signpost/About
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/Years
# /wiki/Wikipedia:Wikipedia_Signpost/Subscribe
# /wiki/Wikipedia_talk:Wikipedia_Signpost/Newsroom
# /wiki/Wikipedia:Wikipedia_Signpost/Next_issue
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom#Article_status
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Submissions
# /wiki/MOS:OP-ED
# /wiki/Wikipedia:Wikipedia_is_not_a_dictionary
# /wiki/Wiktionary
# /wiki/Wikipedia:Wikimedia_sister_projects#How_to_link
# /wiki/Wikipedia_talk:Wikimedia_sister_projects
# /wiki/Wikipedia:Wikimedia_sister_projects
# /wiki/Help:Interwiki_linking
# /wiki/Help:Interlanguage_links
# /wiki/Wikipedia:Manual_of_Style/Linking
# /wiki/Help:Link
# /wiki/Help:List
# /wiki/Wikipedia:Manual_of_Style/Lists
# /wiki/Wikipedia:Lists
# /wiki/Wikipedia:Manual_of_Style/Lists#Bulleted_lists
# /wiki/Wikipedia_talk:Manual_of_Style/Lists
# /wiki/Wikipedia:WikiProject_Manual_of_Style
# /wiki/Wikipedia:WikiProject_Wikipedia
# /wiki/File:Wikipedia-logo-v2.svg
# /wiki/File:Commons-logo.svg
# /wiki/Wikipedia:Copyrights
# /wiki/Wikipedia:Civility
# /wiki/Wikipedia:WikiProject_Cooperation
# /wiki/Wikipedia:Co-op
# /wiki/Wikipedia:HISPAGES
# /wiki/Wikipedia_talk:Project_namespace
# /wiki/Wikipedia:Project_namespace
# /wiki/Category:Wikipedia_guidelines
# /wiki/Category:Wikipedia_policies
# /wiki/Wikipedia:5P
# /wiki/Almanac
# /wiki/Almanac_(disambiguation)
# /wiki/Nautical_almanac
# /wiki/Nautical_almanac_(disambiguation)
# /wiki/The_Nautical_Almanac
# /wiki/Almanacs
# /wiki/Annual_publication
# /wiki/Periodical_publication
# /wiki/Periodicity_(disambiguation)
# /wiki/Bott_periodicity_theorem
# /wiki/Mathematics
# /wiki/Mathematics_(disambiguation)
# /wiki/Mathematics_(album)
# /wiki/Help:Referencing_for_beginners
# /wiki/File:Webcomic_xkcd_-_Wikipedian_protester.png
# /wiki/Wikipedia:Featured_pictures
# /wiki/Wikipedia:Flagged_protection
# /wiki/Wikipedia:PCR
# /wiki/Wikipedia:Banning_policy#Topic_ban
# /wiki/Wikipedia:Spam_blacklist
# /wiki/Wikipedia:Spam-blacklist
# /wiki/Wikipedia:Spam-blacklisting
# /wiki/MediaWiki:Spam-blacklist
# /wiki/MediaWiki_talk:Spam-blacklist/log
# /wiki/MediaWiki_talk:Spam-blacklist
# /wiki/Wikipedia:Skin
# /wiki/Skinnable
# /wiki/Talk:Skin_(computing)
# /wiki/Skin_(computing)
# /wiki/Help:Maintenance_template_removal
# /wiki/Wikipedia:Responsible_tagging
# /wiki/Wikipedia:Tags
# /wiki/Wikipedia:Templates
# /wiki/Wikipedia:Shortcut_index
# /wiki/Wikipedia:Wikipedia_(disambiguation)
# /wiki/Wikipedia:Wikipedia_is_an_encyclopedia
# /wiki/Knowledge
# /wiki/Knowledge_(disambiguation)
# /wiki/Know_(album)
# /wiki/File:Jason_Mraz_Know.jpg
# /wiki/Wikipedia:Non-free_use_rationale_guideline
# /wiki/Category:Wikipedia_content_guidelines
# /wiki/Wikipedia:List_of_guidelines#Content
# /wiki/Wikipedia:List_of_policies
# /wiki/Wikipedia_talk:List_of_policies
# /wiki/File:Peacedove.svg
# /wiki/Special:WhatLinksHere/File:Peacedove.svg
# /wiki/Talk:Kashmir
# /wiki/Kashmir
# /wiki/Kashmir_(disambiguation)
# /wiki/Kashmir_Valley
# /wiki/File:Kashmir-sat-nasa.jpg
# /wiki/Khasas
# /wiki/Khasas_(Mahabharata)
# /wiki/Khas_people
# /wiki/Khasa_Malla_kingdom
# /wiki/File:Crystal_Clear_app_kedit.svg
# /wiki/Crystal_Clear
# /wiki/Crystal_Clear_(Jaci_Velasquez_album)
# /wiki/File:Crystal_Clear_Cover.jpg
# /wiki/Compact_Disc
# /wiki/CD_(disambiguation)
# /wiki/CD
# /wiki/CDS_(disambiguation)
# /wiki/Certificate_of_deposit
# /wiki/Talk:Certificate_of_deposit
# /wiki/Wikipedia:What_Wikipedia_is_not#FORUM
# /wiki/Wikipedia:Content_policies
# /wiki/Wikipedia:Policies_and_guidelines#Conflicts_between_advice_pages
# /wiki/Help:Introduction_to_policies_and_guidelines/1
# /wiki/Help:Introduction_to_policies_and_guidelines
# /wiki/Help:Introduction_to_policies_and_guidelines/2
# /wiki/Help:Introduction_to_policies_and_guidelines/3
# /wiki/Help:Introduction_to_policies_and_guidelines/4
# /wiki/Help:Introduction_to_policies_and_guidelines/All
# /wiki/Wikipedia:Five_pillars
# /wiki/Gazetteer
# /wiki/File:Santa_Fe_Route_Map_1891.jpg
# /wiki/Category:Atchison,_Topeka_and_Santa_Fe_Railway_images
# /wiki/Atchison,_Topeka_and_Santa_Fe_Railway
# /wiki/On_the_Atchison,_Topeka_and_the_Santa_Fe
# /wiki/Popular_music
# /wiki/Pop_music
# /wiki/Pop_music_(disambiguation)
# /wiki/Pop_Muzik
# /wiki/Poppy.Computer
# /wiki/File:Poppy_-_Poppy_Computer.png
# /wiki/Poppy_(entertainer)
# /wiki/File:Poppy_aiagtour.png
# /wiki/Wikipedia:Contents
# /wiki/Wikipedia:Contents/Overviews
# /wiki/Wikipedia:Contents/Outlines
# /wiki/Wikipedia:Contents/Lists
# /wiki/Wikipedia:Contents/Portals
# /wiki/Wikipedia:Contents/A%E2%80%93Z_index
# /wiki/Wikipedia:Contents/Glossaries
# /wiki/Wikipedia:Contents/Categories
# /wiki/Wikipedia:Contents/Indices
# /wiki/Wikipedia:Contents/Reference
# /wiki/Wikipedia:Contents/Culture_and_the_arts
# /wiki/Wikipedia:Contents/Geography_and_places
# /wiki/Special:Nearby
# /wiki/Portal:Current_events
# /wiki/File:Darkgreen_flag_waving.svg
# /wiki/Special:WhatLinksHere/File:Darkgreen_flag_waving.svg
# /wiki/Portal:Biology
# /wiki/Wikipedia:Featured_portals
# /wiki/Wikipedia:Village_pump_(proposals)/RfC:_Ending_the_system_of_portals
# /wiki/Wikipedia:Village_pump
# /wiki/Special:NewSection/Wikipedia:Village_pump_(policy)
# /wiki/Template:Editnotices/Page/Wikipedia:Village_pump_(policy)
# /wiki/Template:Editnotices
# /wiki/Wikipedia:Manual_of_Style/Hidden_text
# /wiki/MOS:DONTHIDE
# /wiki/Category:Wikipedia_Manual_of_Style_(content)
# /wiki/Wikipedia:FAQ/Categorization#Why_might_a_category_list_not_be_up_to_date?
# /wiki/Wikipedia:FAQ/Index
# /wiki/Wikipedia:FAQ/Main
# /wiki/Wikipedia:FAQ/Overview
# /wiki/Wikipedia:FAQ/Schools
# /wiki/Wikipedia:FAQ/Organizations
# /wiki/Wikipedia:FAQ/Contributing
# /wiki/Wikipedia:FAQ/Editing
# /wiki/Wikipedia:FAQ/Featured_articles
# /wiki/Wikipedia:FAQ/Administration
# /wiki/Wikipedia:FAQ/Blocks
# /wiki/Wikipedia:FAQ/Technical
# /wiki/Wikipedia:FAQ/Problems
# /wiki/Wikipedia:FAQ/Article_subjects
# /wiki/Wikipedia:FAQ/Categories
# /wiki/Wikipedia:FAQ_index
# /wiki/Wikipedia:FAQ/Categorization
# /wiki/Wikipedia:FAQ/Copyright
# /wiki/Wikipedia:FAQ/Forking
# /wiki/Wikipedia:FAQ/Template
# /wiki/Wikipedia:FAQ/Miscellaneous
# /wiki/Wikipedia:Wikipedia_logos
# /wiki/Wikipedia:Logos
# /wiki/Wikipedia_talk:Logos
# /wiki/Special:NewSection/Wikipedia_talk:Logos
# /wiki/Wikipedia:Copyright_violations
# /wiki/Wikipedia:NOTCV
# /wiki/Wikipedia:Article_titles
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cec233e25281> in <module>
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
#      27                 getLinks(newPage)
# ---> 28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# ...
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage) # 한 번 들어온 페이지 주소는 pages에 추가
# ---> 27                 getLinks(newPage)
#      28 getLinks('')
#
# <ipython-input-3-cec233e25281> in getLinks(pageUrl)
#      17     global pages
#      18     html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
# ---> 19     bs = BeautifulSoup(html, 'html.parser')
#      20     for link in bs.find_all('a', href=re.compile('^(/wiki/)')): # href 속성값이 '/wiki/'로 시작하는 모든 a태그 하나씩
#      21         if 'href' in link.attrs:
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     346             self.reset()
#     347             try:
# --> 348                 self._feed()
#     349                 success = True
#     350                 break
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     432         self.builder.reset()
#     433
# --> 434         self.builder.feed(self.markup)
#     435         # Close out any unfinished strings and close all the open tags.
#     436         self.endData()
#
# ~\anaconda3\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     375         parser.soup = self.soup
#     376         try:
# --> 377             parser.feed(markup)
#     378             parser.close()
#     379         except HTMLParseError as e:
#
# ~\anaconda3\lib\html\parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~\anaconda3\lib\html\parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~\anaconda3\lib\html\parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# ~\anaconda3\lib\site-packages\bs4\builder\_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     149         #print("START", name)
#     150         sourceline, sourcepos = self.getpos()
# --> 151         tag = self.soup.handle_starttag(
#     152             name, None, None, attr_dict, sourceline=sourceline,
#     153             sourcepos=sourcepos
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     694         """
#     695         # print("Start tag %s: %s" % (name, attrs))
# --> 696         self.endData()
#     697
#     698         if (self.parse_only and len(self.tagStack) <= 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        print(bs.find(id ='mw-content-text').find_all('p')[0]) # 가장 상위에 있는 문단 찾음. 
        print(bs.find(id='ca-edit').find('span').find('a').attrs['href']) # 여기서 계속 except문으로 빠짐. 
        # 이렇게 find.find.find... 면 무.조.건. AttributeError 예외처리 필요!!
        # None을 받아오는 것까지는 Okay인데, None.find 가 되면 AttributeError!
        
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage) # 재귀함수
getLinks('') 
'''
Main Page
<p><i><b><a href="/wiki/The_Thankful_Poor" title="The Thankful Poor">The Thankful Poor</a></b></i> is an 1894 painting by the African-American painter <a href="/wiki/Henry_Ossawa_Tanner" title="Henry Ossawa Tanner">Henry Ossawa Tanner</a>. It is a <a href="/wiki/Genre_painting" title="Genre painting">genre painting</a> of two African Americans praying at a table and shares themes with Tanner's other works like <i><a href="/wiki/The_Banjo_Lesson" title="The Banjo Lesson">The Banjo Lesson</a></i> (1893). The painting is considered a milestone in <a href="/wiki/African-American_art" title="African-American art">African-American art</a>, notably for its countering of racial stereotypes by portraying <a href="/wiki/African-American_culture" title="African-American culture">African-American culture</a> in a dignified manner. This depiction was influenced by <a href="/wiki/Benjamin_Tucker_Tanner" title="Benjamin Tucker Tanner">Tanner's father</a> and the <a href="/wiki/African_Methodist_Episcopal_Church" title="African Methodist Episcopal Church">African Methodist Episcopal Church</a>. Despite its popularity with critics, <i>The Thankful Poor</i> was Tanner's last African-American genre work before he began to focus on biblical scenes. After remaining hidden for years, the painting was discovered in a storage closet of the <a href="/wiki/Pennsylvania_School_for_the_Deaf" title="Pennsylvania School for the Deaf">Pennsylvania School for the Deaf</a> in 1970, before being purchased by <a href="/wiki/Camille_Cosby" title="Camille Cosby">Camille</a> and <a href="/wiki/Bill_Cosby" title="Bill Cosby">Bill Cosby</a> in 1981 for their <a href="/wiki/Camille_O._and_William_H._Cosby_Collection_of_African_American_Art" title="Camille O. and William H. Cosby Collection of African American Art">private collection</a>. In 2020, the painting was sold by the Cosbys to Art Bridges, a foundation created by <a href="/wiki/Alice_Walton" title="Alice Walton">Alice Walton</a> for loaning artwork. (<b><a href="/wiki/The_Thankful_Poor" title="The Thankful Poor">Full article...</a></b>)
</p>
This page is missing something! Continuing.
--------------------
/wiki/Wikipedia
Wikipedia
<p class="mw-empty-elt">
</p>
This page is missing something! Continuing.
--------------------
/wiki/Wikipedia:Protection_policy#semi
Wikipedia:Protection policy
<p class="mw-empty-elt">
</p>
This page is missing something! Continuing.
--------------------
  ㆍㆍㆍ
'''
# Out:
# Main Page
# <p><i><b><a href="/wiki/The_Thankful_Poor" title="The Thankful Poor">The Thankful Poor</a></b></i> is an 1894 painting by the African-American painter <a href="/wiki/Henry_Ossawa_Tanner" title="Henry Ossawa Tanner">Henry Ossawa Tanner</a>. It is a <a href="/wiki/Genre_painting" title="Genre painting">genre painting</a> of two African Americans praying at a table and shares themes with Tanner's other works like <i><a href="/wiki/The_Banjo_Lesson" title="The Banjo Lesson">The Banjo Lesson</a></i> (1893). The painting is considered a milestone in <a href="/wiki/African-American_art" title="African-American art">African-American art</a>, notably for its countering of racial stereotypes by portraying <a href="/wiki/African-American_culture" title="African-American culture">African-American culture</a> in a dignified manner. This depiction was influenced by <a href="/wiki/Benjamin_Tucker_Tanner" title="Benjamin Tucker Tanner">Tanner's father</a> and the <a href="/wiki/African_Methodist_Episcopal_Church" title="African Methodist Episcopal Church">African Methodist Episcopal Church</a>. Despite its popularity with critics, <i>The Thankful Poor</i> was Tanner's last African-American genre work before he began to focus on biblical scenes. After remaining hidden for years, the painting was discovered in a storage closet of the <a href="/wiki/Pennsylvania_School_for_the_Deaf" title="Pennsylvania School for the Deaf">Pennsylvania School for the Deaf</a> in 1970, before being purchased by <a href="/wiki/Camille_Cosby" title="Camille Cosby">Camille</a> and <a href="/wiki/Bill_Cosby" title="Bill Cosby">Bill Cosby</a> in 1981 for their <a href="/wiki/Camille_O._and_William_H._Cosby_Collection_of_African_American_Art" title="Camille O. and William H. Cosby Collection of African American Art">private collection</a>. In 2020, the painting was sold by the Cosbys to Art Bridges, a foundation created by <a href="/wiki/Alice_Walton" title="Alice Walton">Alice Walton</a> for loaning artwork. (<b><a href="/wiki/The_Thankful_Poor" title="The Thankful Poor">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia
# Wikipedia
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Protection_policy#semi
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Requests_for_page_protection
# Wikipedia:Requests for page protection
# <p>This page is for requesting that a page, file or template be <strong>fully protected</strong>, <strong>create protected</strong> (<a href="/wiki/Wikipedia:Protection_policy#Creation_protection" title="Wikipedia:Protection policy">salted</a>), <strong>extended confirmed protected</strong>, <strong>semi-protected</strong>, added to <strong>pending changes</strong>, <strong>move-protected</strong>, <strong>template protected</strong>, <strong>upload protected</strong> (file-specific), or <strong>unprotected</strong>. Please read the <a href="/wiki/Wikipedia:Protection_policy" title="Wikipedia:Protection policy">protection policy</a> for details. Full protection is used to stop edit warring between multiple users or to prevent vandalism to <a href="/wiki/Wikipedia:High-risk_templates" title="Wikipedia:High-risk templates">high-risk templates</a>; semi-protection and pending changes are usually used only to prevent IP and new user vandalism (see the <a href="/wiki/Wikipedia:Rough_guide_to_semi-protection" title="Wikipedia:Rough guide to semi-protection">rough guide to semi-protection</a>); and move protection is used to stop <a href="/wiki/Wikipedia:Page-move_war" title="Wikipedia:Page-move war">page-move wars</a>. Extended confirmed protection is used where semi-protection has proved insufficient (see the <a href="/wiki/Wikipedia:Rough_guide_to_extended_confirmed_protection" title="Wikipedia:Rough guide to extended confirmed protection">rough guide to extended confirmed protection</a>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Requests_for_permissions
# Wikipedia:Requests for permissions
# <p><span class="sysop-show" id="coordinates"><a href="/wiki/Wikipedia:Requests_for_permissions/Administrator_instructions" title="Wikipedia:Requests for permissions/Administrator instructions">Administrator instructions</a></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Protection_policy#extended
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Lists_of_protected_pages
# Wikipedia:Lists of protected pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Protection_policy
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Perennial_proposals
# Wikipedia:Perennial proposals
# <p>This is a list of things that have frequently been proposed on Wikipedia, and have been <a class="mw-redirect" href="/wiki/Wikipedia:Rejected_proposals" title="Wikipedia:Rejected proposals">rejected by the community</a> several times in the past. It should be noted that merely listing something on this page does not mean it will never happen, but that it has been discussed before and never met consensus.  <a class="mw-redirect" href="/wiki/Wikipedia:Consensus_can_change" title="Wikipedia:Consensus can change">Consensus can change</a>, and some proposals that remained on this page for a long time have finally been proposed in a way that reached consensus, but you should address rebuttals raised in the past if you make a proposal along these lines.  If you feel you would still like to do one of these proposals, then raise it at the <a href="/wiki/Wikipedia:Village_pump" title="Wikipedia:Village pump">village pump</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# Wikipedia:Reliable sources/Perennial sources
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Reliable_sources
# Wikipedia:Reliable sources
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WikiProject_Reliability
# Wikipedia:WikiProject Reliability
# <p>Hello, and welcome to <b>WikiProject Reliability</b>. This WikiProject is dedicated to improving the <a class="mw-redirect" href="/wiki/Wikipedia:RS" title="Wikipedia:RS">reliability</a> of Wikipedia articles. We ensure that articles are supported by <a class="mw-redirect" href="/wiki/Wikipedia:RS" title="Wikipedia:RS">reliable sources</a>, answer inquiries on the <a class="mw-redirect" href="/wiki/Wikipedia:RSN" title="Wikipedia:RSN">reliable sources noticeboard</a>, and maintain a <a class="mw-redirect" href="/wiki/Wikipedia:RSP" title="Wikipedia:RSP">list of frequently discussed sources</a>. This project works to achieve the goals of the <a class="mw-redirect" href="/wiki/Wikipedia:V" title="Wikipedia:V">verifiability</a> and <a class="mw-redirect" href="/wiki/Wikipedia:OR" title="Wikipedia:OR">no original research</a> policies. If you would like to help, please <a href="#Participants">join</a> the project, participate on the <a href="/wiki/Wikipedia_talk:WikiProject_Reliability" title="Wikipedia talk:WikiProject Reliability">talk page</a> and see the <a href="#Open_tasks">open tasks</a> below.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WRE
# Wikipedia:WikiProject Resource Exchange
# <p><b>Shortcuts</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:People_icon.svg
# File:People icon.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/3/37/People_icon.svg" title="People icon.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 100 × 100 pixels, file size: 22 KB)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# Pages that link to "File:People icon.svg"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/File:People_icon.svg" title="File:People icon.svg">File:People icon.svg</a></b> <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:What_links_here
# Help:What links here
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# Wikipedia:Project namespace
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Protection_policy#move
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WikiProject_Parliamentary_Procedure
# Wikipedia:WikiProject Parliamentary Procedure
# <p><b>WikiProject Parliamentary Procedure</b> is devoted to improving the quality and comprehensiveness of articles on topics related to [[parliamentary proyOpen main menu
# Wikipedia's
# M
# Search
# Wikipedia:WikiProject Parliamentary Procedure
# Language's
# Watch
# Edit
# This WikiProject is believed to be inactive.
# If you are not currently a member of the project, you may still want to consider joining it. This status should be changed if any activity resumes.
# Guide to WikiProjects Directory of WikiProjects Dealing with inactive WikiProjects
# WikiProject Parliamentary Procedure is devoted to improving the quality and comprehensiveness of articles on topics related to parliamentary procedure.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:People_icon_dead.svg
# File:People icon dead.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/6/6b/People_icon_dead.svg" title="People icon dead.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 100 × 100 pixels, file size: 24 KB)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/User:StevenDH
# User:StevenDH
# <p><br/>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:User_pages
# Wikipedia:User pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:FUW
# Wikipedia:File Upload Wizard
# <p>Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Protection_policy#template
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Party_and_person
# Wikipedia:Party and person
# <p>Different content policies and guidelines use slightly different standards.  One of the commonly misunderstood distinctions is between "secondary source" and "third party".
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:Essay.svg
# File:Essay.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/7/7e/Essay.svg" title="Essay.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 35 × 42 pixels, file size: 17 KB)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:Essay.png
# File:Wikipedia Essay icon.png
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/2/2d/Wikipedia_Essay_icon.png" title="Wikipedia Essay icon.png">Wikipedia_Essay_icon.png</a> ‎<span class="fileInfo">(30 × 35 pixels, file size: 2 KB, MIME type: <span class="mime-type">image/png</span>)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:To_Commons.svg
# File:To Commons.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/7/78/To_Commons.svg" title="To Commons.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 913 × 913 pixels, file size: 200 KB)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# Pages that link to "File:To Commons.svg"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/File:To_Commons.svg" title="File:To Commons.svg">File:To Commons.svg</a></b> <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/User_talk:Robert_Merkel
# User talk:Robert Merkel
# <p><a href="/wiki/User_talk:Robert_Merkel/ancient" title="User talk:Robert Merkel/ancient">User talk:Robert Merkel/ancient</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_1" title="User talk:Robert Merkel/archive 1">User talk:Robert Merkel/archive 1</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_2" title="User talk:Robert Merkel/archive 2">User talk:Robert Merkel/archive 2</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_3" title="User talk:Robert Merkel/archive 3">User talk:Robert Merkel/archive 3</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_4" title="User talk:Robert Merkel/archive 4">User talk:Robert Merkel/archive 4</a>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/User_talk:Robert_Merkel/ancient
# User talk:Robert Merkel/ancient
# <p>Did you write the Bradman article?  If so, good work.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/User:RjLesch
# User:RjLesch
# <p>Database developer and project manager, <a href="/wiki/Des_Moines,_Iowa" title="Des Moines, Iowa">Des Moines, Iowa</a>, <a class="mw-redirect" href="/wiki/United_States_of_America" title="United States of America">United States of America</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Des_Moines,_Iowa
# Des Moines, Iowa
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Des_Moines_(disambiguation)
# Des Moines (disambiguation)
# <p><b><a href="/wiki/Des_Moines,_Iowa" title="Des Moines, Iowa">Des Moines</a></b> is the capital of the state of Iowa in the United States.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Des_Moines_metropolitan_area
# Des Moines metropolitan area
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Metropolitan_statistical_area
# Metropolitan statistical area
# <p><span style="font-size:110%;"><a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">Population</a></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/List_of_metropolitan_statistical_areas
# List of metropolitan statistical areas
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/List_of_primary_statistical_areas_of_the_United_States
# Statistical area (United States)
# <p><span style="font-size:110%;"><a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">Population</a></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:Pano_Manhattan2007_amk.jpg
# File:Pano Manhattan2007 amk.jpg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/8/8d/Pano_Manhattan2007_amk.jpg" title="Pano Manhattan2007 amk.jpg">Original file</a> ‎<span class="fileInfo">(2,764 × 800 pixels, file size: 1.61 MB, MIME type: <span class="mime-type">image/jpeg</span>)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/User:AngMoKio
# User:AngMoKio
# <p><b>If you want to contact me than please do that on my Commons-Account <a class="external text" href="https://commons.wikimedia.org/wiki/User:AngMoKio">(AngMoKio)</a></b><br/>
# <b>My old account was <a class="mw-redirect" href="/wiki/User:AngMo" title="User:AngMo">AngMo</a>!</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Babel
# Wikipedia:Babel
# <p>On Wikimedia projects, the noun <b>Babel</b> (an <a href="/wiki/Allusion" title="Allusion">allusion</a> to the <a href="/wiki/Tower_of_Babel" title="Tower of Babel">Tower of Babel</a>) refers to the <b>user language templates</b> aiding multilingual communication by making it easier to contact someone who speaks a certain language. The idea originated on the <a class="extiw" href="https://commons.wikimedia.org/wiki/Commons:Babel" title="commons:Commons:Babel">Wikimedia Commons</a> and has also been implemented on <a class="extiw" href="https://meta.wikimedia.org/wiki/Meta:Babel_templates" title="meta:Meta:Babel templates">Meta-Wiki</a> and some of the other Wikipedias to varying extents. To participate, you can add the Babel template to your user page by following the instructions below.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/List_of_ISO_639-1_codes
# List of ISO 639-1 codes
# <p>ISO 639 is a standardized nomenclature used to classify languages. Each language is assigned a two-letter (639-1) and three-letter (<span class="nowrap">639-2</span> and <span class="nowrap">639-3</span>) lowercase abbreviation, amended in later versions of the nomenclature.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:Question_book-new.svg
# File:Question book-new.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/9/99/Question_book-new.svg" title="Question book-new.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 512 × 399 pixels, file size: 6 KB)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Scalable_Vector_Graphics
# Scalable Vector Graphics
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/SVG_(disambiguation)
# SVG (disambiguation)
# <p><b><a class="mw-redirect" href="/wiki/SVG" title="SVG">SVG</a></b> or Scalable Vector Graphics is a vector image format for two-dimensional computer graphics.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/SVG
# Scalable Vector Graphics
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:SVG_help
# Wikipedia:SVG help
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Graphic_Lab/Resources/SVG
# Wikipedia:Graphics Lab/Resources/SVG
# <p><a class="mw-redirect" href="/wiki/SVG" title="SVG">SVG</a> (Scalable Vector Graphics) resources. Why SVG, one might ask? Look to the image on the right. SVG images stored at Wikipedia or on the <a href="/wiki/Wikimedia_Commons" title="Wikimedia Commons">Wikimedia Commons</a> aren't actually what you see in your browser when viewing Wikipedia articles. <a href="/wiki/MediaWiki" title="MediaWiki">MediaWiki</a> converts the SVG image to a <a href="/wiki/Portable_Network_Graphics" title="Portable Network Graphics">PNG</a> image. The SVG format is the working format of the stored image so that people can more easily convert images for use in different languages. If you're using a browser other than <a href="/wiki/Internet_Explorer" title="Internet Explorer">Internet Explorer</a>, just keep clicking the image and you'll eventually get the full-size image, which will be the SVG version. For example; keep clicking the image to the right. For more info please see: <a class="extiw" href="https://commons.wikimedia.org/wiki/Commons:File_types#SVG" title="commons:Commons:File types">Commons:File types#SVG</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Graphics_Lab
# Wikipedia:Graphics Lab
# <p>The <b>Graphics Lab</b> helps improve all graphical content stored on <a class="extiw" href="https://commons.wikimedia.org/wiki/Main_Page" title="commons:Main Page">Wikimedia Commons</a> and the English Wikipedia.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Graphics_Lab/Illustration_workshop
# Wikipedia:Graphics Lab/Illustration workshop
# <p>The <b><a href="/wiki/Wikipedia:Graphics_Lab" title="Wikipedia:Graphics Lab">Graphics Lab</a></b> is a project to improve the graphical content of the Wikimedia projects. Requests for image improvements can be added to the workshop pages: <a class="mw-redirect" href="/wiki/Wikipedia:GL/ILL" title="Wikipedia:GL/ILL">Illustrations</a>, <a class="mw-redirect" href="/wiki/Wikipedia:GL/PHOTO" title="Wikipedia:GL/PHOTO">Photographs</a> and <a class="mw-redirect" href="/wiki/Wikipedia:GL/MAP" title="Wikipedia:GL/MAP">Maps</a>. For questions or suggestions one can use the talk pages: <a href="/wiki/Wikipedia_talk:Graphics_Lab" title="Wikipedia talk:Graphics Lab">Talk:Graphics Lab</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Illustration_workshop" title="Wikipedia talk:Graphics Lab/Illustration workshop">Talk:Illustrations</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Photography_workshop" title="Wikipedia talk:Graphics Lab/Photography workshop">Talk:Photographs</a> and <a href="/wiki/Wikipedia_talk:Graphics_Lab/Map_workshop" title="Wikipedia talk:Graphics Lab/Map workshop">Talk:Maps</a>.<br/>
# <b>This specific page</b> is the requests page for the illustration workshop. Anyone can make a request for an illustration to be improved or created for a Wikipedia article.  Clicking the "New Request" button will bring you to a standard template for submitting requests, as well as general advice that should be followed.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Graphics_Lab/Photography_workshop
# Wikipedia:Graphics Lab/Photography workshop
# <p>The <b><a href="/wiki/Wikipedia:Graphics_Lab" title="Wikipedia:Graphics Lab">Graphics Lab</a></b> is a project to improve the graphical content of the Wikimedia projects. Requests for image improvements can be added to the workshop pages: <a class="mw-redirect" href="/wiki/Wikipedia:GL/ILL" title="Wikipedia:GL/ILL">Illustrations</a>, <a class="mw-redirect" href="/wiki/Wikipedia:GL/PHOTO" title="Wikipedia:GL/PHOTO">Photographs</a> and <a class="mw-redirect" href="/wiki/Wikipedia:GL/MAP" title="Wikipedia:GL/MAP">Maps</a>. For questions or suggestions one can use the talk pages: <a href="/wiki/Wikipedia_talk:Graphics_Lab" title="Wikipedia talk:Graphics Lab">Talk:Graphics Lab</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Illustration_workshop" title="Wikipedia talk:Graphics Lab/Illustration workshop">Talk:Illustrations</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Photography_workshop" title="Wikipedia talk:Graphics Lab/Photography workshop">Talk:Photographs</a> and <a href="/wiki/Wikipedia_talk:Graphics_Lab/Map_workshop" title="Wikipedia talk:Graphics Lab/Map workshop">Talk:Maps</a>.<br/>
# <b>This specific page</b> is the requests page for the photography workshop. Anyone can make a request for a photograph to be improved for a Wikipedia article. The standard format for making a request is shown below, along with general advice, and should be followed.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Graphics_Lab/Map_workshop
# Wikipedia:Graphics Lab/Map workshop
# <p>The <b><a href="/wiki/Wikipedia:Graphics_Lab" title="Wikipedia:Graphics Lab">Graphics Lab</a></b> is a project to improve the graphical content of the Wikimedia projects. Requests for image improvements can be added to the workshop pages: <a class="mw-redirect" href="/wiki/Wikipedia:GL/ILL" title="Wikipedia:GL/ILL">Illustrations</a>, <a class="mw-redirect" href="/wiki/Wikipedia:GL/PHOTO" title="Wikipedia:GL/PHOTO">Photographs</a> and <a class="mw-redirect" href="/wiki/Wikipedia:GL/MAP" title="Wikipedia:GL/MAP">Maps</a>. For questions or suggestions one can use the talk pages: <a href="/wiki/Wikipedia_talk:Graphics_Lab" title="Wikipedia talk:Graphics Lab">Talk:Graphics Lab</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Illustration_workshop" title="Wikipedia talk:Graphics Lab/Illustration workshop">Talk:Illustrations</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Photography_workshop" title="Wikipedia talk:Graphics Lab/Photography workshop">Talk:Photographs</a> and <a href="/wiki/Wikipedia_talk:Graphics_Lab/Map_workshop" title="Wikipedia talk:Graphics Lab/Map workshop">Talk:Maps</a>.<br/>
# <b>This specific page</b> is the requests page for the Map workshop. Anyone can make a request for a map to be created or improved for a Wikipedia article. The standard format for making a request is shown below, along with general advice, and should be followed.<br/>
# You are encouraged to share information and request advice from others. Also see <a href="/wiki/Wikipedia:WikiProject_Maps/Conventions" title="Wikipedia:WikiProject Maps/Conventions">possible conventions toolbox</a>, <a href="/wiki/Wikipedia:Graphics_Lab/Resources/Tutorials" title="Wikipedia:Graphics Lab/Resources/Tutorials">map tutorials</a> and <a href="/wiki/User:JaneVannin/translations" title="User:JaneVannin/translations">topographic map tutorials</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Shortcut
# Wikipedia:Shortcut
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Keyboard_shortcuts
# Wikipedia:Keyboard shortcuts
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WikiProject_Kansas
# Wikipedia:WikiProject Kansas
# <p><span style="font-size:100%;font-weight:bold;border: none; margin: 0; padding:0; padding-bottom:.1em; color:#FFD700;"><a class="image" href="/wiki/File:Seal_of_Kansas.svg"><img alt="Seal of Kansas.svg" data-file-height="600" data-file-width="600" decoding="async" height="48" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/Seal_of_Kansas.svg/48px-Seal_of_Kansas.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/Seal_of_Kansas.svg/72px-Seal_of_Kansas.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/45/Seal_of_Kansas.svg/96px-Seal_of_Kansas.svg.png 2x" width="48"/></a><br/><i>Welcome</i></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WikiProject
# Wikipedia:WikiProject
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/WikiProject
# WikiProject
# <p>A <b>WikiProject</b>, or <b>Wikiproject</b>, is the organization of a group of participants in a <a href="/wiki/Wiki" title="Wiki">wiki</a> established in order to achieve specific editing goals, or to achieve goals relating to a specific field of knowledge. WikiProjects are prevalent within the largest wiki, <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a>, and exist to varying degrees within <a class="mw-redirect" href="/wiki/Wikimedia_project" title="Wikimedia project">sister projects</a> such as <a href="/wiki/Wiktionary" title="Wiktionary">Wiktionary</a>, <a href="/wiki/Wikiquote" title="Wikiquote">Wikiquote</a>, <a href="/wiki/Wikidata" title="Wikidata">Wikidata</a>, and <a href="/wiki/Wikisource" title="Wikisource">Wikisource</a>. They also exist in different languages, and translation of articles is a form of their collaboration. Unrelated wikis have also used the term, for example <a href="/wiki/OpenStreetMap" title="OpenStreetMap">OpenStreetMap</a>.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup> During the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>, <a href="/wiki/CBS_News" title="CBS News">CBS News</a> noted the role of Wikipedia's WikiProject Medicine in maintaining the accuracy of articles related to the disease.<sup class="reference" id="cite_ref-COVID-19_2-0"><a href="#cite_note-COVID-19-2">[2]</a></sup> Another WikiProject that has drawn attention is WikiProject Women Scientists, which was profiled by <i><a class="mw-redirect" href="/wiki/Smithsonian_Magazine" title="Smithsonian Magazine">Smithsonian Magazine</a></i> for its efforts to improve coverage of women scientists which the profile noted had "helped increase the number of female scientists on Wikipedia from around 1,600 to over 5,000".<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wiki
# Wiki
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:En-Wiki2.ogg
# File:En-Wiki2.ogg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/a/a3/En-Wiki2.ogg" title="En-Wiki2.ogg">En-Wiki2.ogg</a> ‎<span class="fileInfo">(Ogg Vorbis sound file, length 15 min 36 s, 83 kbps)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/User:Dmcdevit
# User:Dominic
# <p><br/>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM-Wiki
# Wikipedia:GLAM
# <p><br/>
# <span style="font-size:larger;">The <b>GLAM–Wiki initiative</b> ("galleries, libraries, archives, and museums" with Wikipedia; also including botanic gardens and zoos) helps cultural institutions share their resources with the world through collaborative projects with experienced Wikipedia editors.</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM/About
# Wikipedia:GLAM/About
# <p>The GLAM–Wiki initiative (galleries, libraries, archives, museums with Wikipedia) helps cultural institutions share their resources with the world through high-impact collaboration alongside experienced Wikipedia editors. It is an unparalleled opportunity for the custodians of our cultural heritage to present their collections to new audiences.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM
# Wikipedia:GLAM
# <p><br/>
# <span style="font-size:larger;">The <b>GLAM–Wiki initiative</b> ("galleries, libraries, archives, and museums" with Wikipedia; also including botanic gardens and zoos) helps cultural institutions share their resources with the world through collaborative projects with experienced Wikipedia editors.</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM/Contribute
# Wikipedia:GLAM/Contribute
# <p><a class="image" href="/wiki/File:1NumberOneInCircle.png"><img alt="1NumberOneInCircle.png" data-file-height="500" data-file-width="500" decoding="async" height="30" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/58/1NumberOneInCircle.png/30px-1NumberOneInCircle.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/58/1NumberOneInCircle.png/45px-1NumberOneInCircle.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/58/1NumberOneInCircle.png/60px-1NumberOneInCircle.png 2x" width="30"/></a> Consider content that has no copyright restrictions and can easily enrich Wikipedia articles:
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM/Connect
# Wikipedia:GLAM/Connect
# <p>For GLAM projects worldwide, many of which are based around partnerships with GLAM professional organisations, see <a href="/wiki/Wikipedia:GLAM/Projects" title="Wikipedia:GLAM/Projects">Wikipedia:GLAM/Projects</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM/Bookshelf
# Wikipedia:GLAM/Bookshelf
# <p>/ <a class="external text" href="http://openvideoalliance.org/wiki/index.php?title=Video_for_Wikipedia_and_the_Open_Web:_A_Guide_to_Best_Practices_for_Cultural_and_Educational_Institutions" rel="nofollow">Raw text</a>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM/Projects
# Wikipedia:GLAM/Projects
# <p>This page contains a partial list of the GLAM-Wikimedia collaboration projects; a guide to model GLAM projects, can be found at <a class="extiw" href="https://outreach.wikimedia.org/wiki/GLAM/Model_projects" title="outreach:GLAM/Model projects">on Outreach Wiki</a> documenting successful collaborations also in Wikipedia in languages other than English, Wikimedia Commons, Wikidata and Wikisource.
# <br/>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM/Beginner%27s_guide_to_Wikipedia
# Wikipedia:GLAM/Beginner's guide to Wikipedia
# <p><i><b>If you would like more general information on why you should contribute to Wikipedia, please see <a href="/wiki/Wikipedia:GLAM/Contribute" title="Wikipedia:GLAM/Contribute">GLAM:Contribute</a></b></i>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:GLAM/Newsletter
# Wikipedia:GLAM/Newsletter
# <p>To assist with preparing the newsletter, please visit the <a class="extiw" href="https://outreach.wikimedia.org/wiki/GLAM/Newsletter/Newsroom" title="outreach:GLAM/Newsletter/Newsroom">newsroom</a>. Past editions may be viewed <a class="extiw" href="https://outreach.wikimedia.org/wiki/GLAM/Newsletter/Archives" title="outreach:GLAM/Newsletter/Archives">here</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyTalk
# User talk:106.241.43.86
# <p><b>Other reasons this message may be displayed:</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:NewSection/User_talk:106.241.43.86
# Creating User talk:106.241.43.86
# <p><img alt="Information icon4.svg" data-file-height="620" data-file-width="620" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1d/Information_icon4.svg/20px-Information_icon4.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1d/Information_icon4.svg/30px-Information_icon4.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1d/Information_icon4.svg/40px-Information_icon4.svg.png 2x" width="20"/> <i>Content that <a href="/wiki/Wikipedia:Copyright_violations" title="Wikipedia:Copyright violations">violates any copyrights</a> will be deleted. Encyclopedic content must be <a href="/wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1" title="Help:Introduction to referencing with Wiki Markup/1">verifiable</a>. Any work submitted to Wikipedia can be edited, used, and redistributed—by anyone—subject to <a href="/wiki/Wikipedia:Reusing_Wikipedia_content" title="Wikipedia:Reusing Wikipedia content">certain terms and conditions</a>.</i>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:User-info.svg
# File:User-info.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/c/ce/User-info.svg" title="User-info.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 48 × 48 pixels, file size: 20 KB)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:Full-protection-shackle.svg
# File:Full-protection-shackle.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/4/44/Full-protection-shackle.svg" title="Full-protection-shackle.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 512 × 512 pixels, file size: 729 bytes)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Criteria_for_speedy_deletion#F8
# Wikipedia:Criteria for speedy deletion
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Revision_deletion
# Wikipedia:Revision deletion
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Deletion_review
# Wikipedia:Deletion review
# <p><span id="coordinates"><a href="/wiki/Wikipedia:Deletion_review/Administrator_instructions" title="Wikipedia:Deletion review/Administrator instructions">Administrator instructions</a></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Deletion_discussions
# Wikipedia:Deletion process
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Deletion_policy
# Wikipedia:Deletion policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Deletion_process
# Wikipedia:Deletion process
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Guide_to_deletion
# Wikipedia:Guide to deletion
# <p><b>Deletion of a Wikipedia page</b> removes the complete page (and all previous versions) from public view. Deletion happens when a page is unsuitable, unhelpful, or does not meet the required criteria. <b>Two further <a class="mw-redirect" href="/wiki/Wikipedia:Deletion_processes" title="Wikipedia:Deletion processes">deletion processes</a> exist</b> to address undesirable material that may have been added to a page or visible in a log. The <a href="/wiki/Wikipedia:Deletion_policy" title="Wikipedia:Deletion policy">deletion policy</a> explains when deletion is acceptable.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:General_disclaimer
# Wikipedia:General disclaimer
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Protection_policy#full
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Child_protection
# Wikipedia:Child protection
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Biographies_of_living_persons
# Wikipedia:Biographies of living persons
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Notability_(people)
# Wikipedia:Notability (people)
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:BIO
# Wikipedia:Notability (people)
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Autobiography
# Wikipedia:Autobiography
# <p>Writing an <b><a href="/wiki/Autobiography" title="Autobiography">autobiography</a></b> on Wikipedia is an example of <a class="mw-redirect" href="/wiki/Wikipedia:COI" title="Wikipedia:COI">conflict of interest editing</a> and is <i>strongly </i> discouraged. Editing a biography about yourself is acceptable only if you are removing unambiguous vandalism or clear-cut and serious violations of our <a class="mw-redirect" href="/wiki/Wikipedia:BLP" title="Wikipedia:BLP">biography of living persons policy</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:AUTOBLOCK
# Wikipedia:Autoblock
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Template:Autoblock
# Template:Autoblock
# <p><b>Clearing an autoblock</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Autoblock
# Wikipedia:Autoblock
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:UTRS
# Wikipedia:Unblock Ticket Request System
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:OTRS
# Wikipedia:Volunteer Response Team
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:OTRS_noticeboard
# Wikipedia:OTRS noticeboard
# <p>Wikimedia's <a href="/wiki/Wikipedia:Volunteer_Response_Team" title="Wikipedia:Volunteer Response Team">volunteer response team</a> (OTRS) handles copyright permissions, email inquiries from the public, reuse inquiries, article errors, and a wide range of non-public inquiries. The email service is operated and managed by a <a class="extiw" href="https://foundation.wikimedia.org/wiki/Our_projects" title="foundation:Our projects">cross-project</a> team of volunteers at the <a class="extiw" href="https://meta.wikimedia.org/wiki/" title="meta:">Meta-Wiki</a> level and not by the English Wikipedia community. Actions by OTRS volunteers on English Wikipedia are ultimately subject to review by the <a href="/wiki/Wikipedia:Arbitration_Committee" title="Wikipedia:Arbitration Committee">Arbitration Committee</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Template:Noticeboard_links
# Template:Noticeboard links
# <p><code>{{Noticeboard links |state=uncollapsed |nostb=yes}}</code>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Template_talk:Noticeboard_links
# Template talk:Noticeboard links
# <p>The result of the move request was <b>moved to <a href="/wiki/Template:Noticeboard_links" title="Template:Noticeboard links">Template:Noticeboard links</a>.</b> –<b><a href="/wiki/User:Juliancolton" title="User:Juliancolton"><span style="font-family:Script MT;color:#36648B">Juliancolton</span></a></b> | <a href="/wiki/User_talk:Juliancolton" title="User talk:Juliancolton"><sup><span style="font-family:Verdana;color:gray"><i>Talk</i></span></sup></a> 00:21, 6 September 2009 (UTC)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Talk_page_guidelines
# Wikipedia:Talk page guidelines
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Talk_pages
# Help:Talk pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Template
# Help:Template
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Template_index
# Wikipedia:Template index
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/MOS:TM
# Wikipedia:Manual of Style/Trademarks
# <p><b><a href="/wiki/Trademark" title="Trademark">Trademarks</a></b> include words and short phrases used by legal entities to identify themselves and their products and services. Often, these names are written in several ways with variations in capitalization, punctuation, and formatting. The advice in this page also applies to names and phrases used to identify individuals, movements, groups, forums, projects, events, and other non-commercial entities and their output.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Manual_of_Style
# Wikipedia:Manual of Style
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Policies_and_guidelines#guide
# Wikipedia:Policies and guidelines
# <p>Wikipedia's <b>policies and guidelines</b> are developed by the community to describe best practices, clarify principles, resolve conflicts, and otherwise further our goal of creating a free, reliable encyclopedia. There is no need to read any policy or guideline pages to start editing. The <a href="/wiki/Wikipedia:Five_pillars" title="Wikipedia:Five pillars">five pillars</a> are a popular summary of the most pertinent principles.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WikiProject_Politics
# Wikipedia:WikiProject Politics
# <p>Welcome to <b>WikiProject Politics</b>. A <a href="/wiki/Wikipedia:WikiProject" title="Wikipedia:WikiProject">WikiProject</a> is a group of pages in the "Wikipedia" <a href="/wiki/Wikipedia:Namespace" title="Wikipedia:Namespace">article namespace</a> that are devoted to the management of a specific topic or family of topics within Wikipedia; and, simultaneously, a <a href="/wiki/Wikipedia:WikiProject_Politics/Participants" title="Wikipedia:WikiProject Politics/Participants">group of editors</a> who use those pages to collaborate on encyclopedic work. It is not a place to write encyclopedia articles directly, but a resource to help coordinate and organize the writing and editing of those articles. This group focuses on articles in the broad field of <a href="/wiki/Politics" title="Politics">Politics</a>.  This page and its subpages contain their suggestions; it is hoped that this project will help to focus the efforts of other Wikipedians. You may sign up for the project on the <a href="/wiki/Wikipedia:WikiProject_Politics/Participants" title="Wikipedia:WikiProject Politics/Participants">Participants</a> list below.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/File:A_coloured_voting_box.svg
# File:A coloured voting box.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/0/01/A_coloured_voting_box.svg" title="A coloured voting box.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 160 × 160 pixels, file size: 11 KB)</span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Category:Wikipedia_files_on_Wikimedia_Commons
# Category:Wikipedia files on Wikimedia Commons
# <p>To put images and media files now available on Commons in this category:
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Category
# Help:Category
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Categorization
# Wikipedia:Categorization
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WikiProject_Cats
# Wikipedia:WikiProject Cats
# <p>Welcome to <b>WikiProject Cats</b>, a <a class="mw-redirect" href="/wiki/Wikiproject" title="Wikiproject">wikiproject</a> dedicated to improving to Wikipedia's articles relating to the family of mammals known as the <a href="/wiki/Felidae" title="Felidae">Felidae</a> and commonly referred to as "cats". Any editor can help contribute to this project by looking at the tasks listed here to find something in their interest or inquire on the <a href="/wiki/Wikipedia_talk:WikiProject_Cats" title="Wikipedia talk:WikiProject Cats">talk page</a>. Anyone seeking to join should add their name to the <a href="/wiki/Wikipedia:WikiProject_Cats/Participants" title="Wikipedia:WikiProject Cats/Participants">list of active participants</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:CATP
# Wikipedia:WikiProject Categories
# <p><b>WikiProject Categories</b> has been set up to help manage the categories of Wikipedia and improve them.  The goal is to categorize all articles in a way that is consistent with the guidelines at <a href="/wiki/Wikipedia:Categorization" title="Wikipedia:Categorization">Wikipedia:Categorization</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WikiProject_Council/Guide
# Wikipedia:WikiProject Council/Guide
# <p>A <b>WikiProject</b> is a group of people who want to work as a team to improve Wikipedia. This <a href="/wiki/Wikipedia:Policies_and_guidelines" title="Wikipedia:Policies and guidelines">guideline</a> outlines the accepted practices for starting and maintaining WikiProjects, as well as some tips for how to organize WikiProjects effectively. For more detailed instructions on how to start a WikiProject, see <a href="/wiki/Wikipedia:WikiProject_Council/Guide/WikiProject" title="Wikipedia:WikiProject Council/Guide/WikiProject">Wikipedia:WikiProject Council/Guide/WikiProject</a>.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:WikiProject_Council
# Wikipedia:WikiProject Council
# ...
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      23                 print(newPage)
#      24                 pages.add(newPage)
# ---> 25                 getLinks(newPage)
#      26 getLinks('')
#
# <ipython-input-4-e3cfbd18a751> in getLinks(pageUrl)
#      10     try:
#      11         print(bs.h1.get_text())
# ---> 12         print(bs.find(id ='mw-content-text').find_all('p')[0])
#      13         print(bs.find(id='ca-edit').find('span').find('a').attrs['href'])
#      14     except AttributeError:
#
# IndexError: list index out of range

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set() # 집합자료형으로 (중복x, 순서x)
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, includeUrl): # 내부링크 : 같은 서버에 있는데, 페이지 주소만 다른 링크
    includeUrl = '{}://{}'.format(urlparse(includeUrl).scheme, urlparse(includeUrl).netloc)
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bs.find_all('a', href=re.compile('^(/|.*'+includeUrl+')')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, excludeUrl): # 외부링크 : 아예 외부 서버에 있는, 서버 자체가 다른 링크
    externalLinks = []
    #Finds all links that start with "http" that do
    #not contain the current URL
    for link in bs.find_all('a', href=re.compile('^(http|www)((?!'+excludeUrl+').)*$')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage) # startingPage 열어서 html 가져옴
    bs = BeautifulSoup(html, 'html.parser') # html 파싱 위한 객체 bs 만듦
    externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc) # 해당 페이지의 모든 externalLinks를 리스트로 담아옴
    if len(externalLinks) == 0: # 하나도 없으면
        print('No external links, looking around the site for one')
        domain = '{}://{}'.format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
        '''
        URL의 일반적인 구조
            => 프로토콜://도메인주소/웹페이지주소/query(파라미터설정값같은것)
            => scheme://netloc/path;parameters?query#fragment
        urlparse(url).scheme → 프로토콜에 해당하는 부분 (http, https) 만 리턴 
        urlparse(url).netloc → 도메인주소에 해당하는 부분만 리턴
        '''
        internalLinks = getInternalLinks(bs, domain) # 해당 페이지의 모든 internalLinks를 리스트로 담아옴
        return getRandomExternalLink(internalLinks[random.randint(0, len(internalLinks)-1)])
    else: # 하나라도 있으면
        return externalLinks[random.randint(0, len(externalLinks)-1)] # externalLinks에서 랜덤으로 링크 하나 뽑아 리턴
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print('Random external link is: {}'.format(externalLink))
    followExternalOnly(externalLink)
            
followExternalOnly('http://oreilly.com')
# Out:
# Random external link is: http://twitter.com/oreillymedia
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a23b136d3234> in <module>()
#      52     followExternalOnly(externalLink)
#      53
# ---> 54 followExternalOnly('http://oreilly.com')
#
# <ipython-input-6-a23b136d3234> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print('Random external link is: {}'.format(externalLink))
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 followExternalOnly('http://oreilly.com')
#
# <ipython-input-6-a23b136d3234> in followExternalOnly(startingSite)
#      48
#      49 def followExternalOnly(startingSite):
# ---> 50     externalLink = getRandomExternalLink(startingSite)
#      51     print('Random external link is: {}'.format(externalLink))
#      52     followExternalOnly(externalLink)
#
# <ipython-input-6-a23b136d3234> in getRandomExternalLink(startingPage)
#      36 def getRandomExternalLink(startingPage):
#      37     html = urlopen(startingPage)
# ---> 38     bs = BeautifulSoup(html, 'html.parser')
#      39     externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc)
#      40     if len(externalLinks) == 0:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     213         parser.soup = self.soup
#     214         try:
# --> 215             parser.feed(markup)
#     216         except HTMLParseError as e:
#     217             warnings.warn(RuntimeWarning(
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     301     def parse_starttag(self, i):
#     302         self.__starttag_text = None
# --> 303         endpos = self.check_for_whole_start_tag(i)
#     304         if endpos < 0:
#     305             return endpos
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in check_for_whole_start_tag(self, i)
#     355         if m:
#     356             j = m.end()
# --> 357             next = rawdata[j:j+1]
#     358             if next == ">":
#     359                 return j + 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = set()
allIntLinks = set()


def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = '{}://{}'.format(urlparse(siteUrl).scheme,
                              urlparse(siteUrl).netloc)
    bs = BeautifulSoup(html, 'html.parser')
    internalLinks = getInternalLinks(bs, domain)
    externalLinks = getExternalLinks(bs, domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)


allIntLinks.add('http://oreilly.com')
getAllExternalLinks('http://oreilly.com')
# Out:
# https://www.oreilly.com
# http://www.oreilly.com/ideas
# https://www.safaribooksonline.com/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170601+nav
# http://www.oreilly.com/conferences/
# http://shop.oreilly.com/
# http://members.oreilly.com
# https://www.oreilly.com/topics
# https://www.safaribooksonline.com/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170505+homepage+get+started+now
# https://www.safaribooksonline.com/accounts/login/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170203+homepage+sign+in
# https://www.safaribooksonline.com/live-training/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170201+homepage+take+a+live+online+course
# https://www.safaribooksonline.com/learning-paths/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170201+homepage+follow+a+path
# https://www.safaribooksonline.com/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170505+homepage+unlimited+access
# http://www.oreilly.com/live-training/?view=grid
# https://www.safaribooksonline.com/your-experience/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170201+homepage+safari+platform
# https://cdn.oreillystatic.com/pdf/oreilly_high_performance_organizations_whitepaper.pdf
# https://www.oreilly.com/ideas/8-data-trends-on-our-radar-for-2017?utm_medium=referral&utm_source=oreilly.com&utm_campaign=lgen&utm_content=link+2017+trends
# https://www.oreilly.com/ideas?utm_medium=referral&utm_source=oreilly.com&utm_campaign=lgen&utm_content=link+read+latest+articles
# http://www.oreilly.com/about/
# http://www.oreilly.com/work-with-us.html
# http://www.oreilly.com/careers/
# http://shop.oreilly.com/category/customer-service.do
# http://www.oreilly.com/about/contact.html
# http://twitter.com/oreillymedia
# http://fb.co/OReilly
# https://www.linkedin.com/company/oreilly-media
# https://www.youtube.com/user/OreillyMedia
# http://www.oreilly.com/emails/newsletters/
# http://www.oreilly.com/terms/
# http://www.oreilly.com/privacy.html
# http://www.oreilly.com/about/editorial_independence.html
# https://www.safaribooksonline.com/home/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170601+nav
# http://www.oreilly.com/emails/newsletters/?display=preview#ai
# https://www.oreilly.com/privacy.html
# http://www.oreilly.com/ai/building-bots-with-natural-language-processing.csp?utm_source=oreilly&utm_medium=newsite&utm_campaign=ai-topic-cta
# https://www.flickr.com/photos/ebmorse/7536436622/in/dateposted/
# http://oreilly.com/about/
# http://oreilly.com/work-with-us.html
# http://oreilly.com/careers/
# https://plus.google.com/+oreillymedia
# http://oreilly.com/terms/
# http://oreilly.com/privacy.html
# https://www.safaribooksonline.com/home/?utm_source=newsite&utm_medium=content&utm_campaign=lgen&utm_content=business-topic-cta
# https://www.flickr.com/photos/pagedooley/4253159181/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-846c414ed600> in <module>()
#      19
#      20 allIntLinks.add('http://oreilly.com')
# ---> 21 getAllExternalLinks('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#      16         if link not in allIntLinks:
#      17             allIntLinks.add(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20 allIntLinks.add('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#      16         if link not in allIntLinks:
#      17             allIntLinks.add(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20 allIntLinks.add('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#      16         if link not in allIntLinks:
#      17             allIntLinks.add(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20 allIntLinks.add('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#      16         if link not in allIntLinks:
#      17             allIntLinks.add(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20 allIntLinks.add('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#       3 allIntLinks = set()
#       4 def getAllExternalLinks(siteUrl):
# ----> 5     html = urlopen(siteUrl)
#       6     domain = '{}://{}'.format(urlparse(siteUrl).scheme, urlparse(siteUrl).netloc)
#       7     bs = BeautifulSoup(html, 'html.parser')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1000                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#    1004             return socket.recv_into(self, buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     863             raise ValueError("Read on closed or unwrapped SSL socket.")
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#     867             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     623         """
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#     627             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
